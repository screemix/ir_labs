# %% [markdown]
# # 0. Short description
#
# In the first part of the lab you are going to implement a standard document processing pipeline and then build a simple search engine based on it:
# - starting from crawling documents,
# - then building an inverted index,
# - and answering queries using this index.
#
# Second part is devoted to spellchecking. You will implement some functions related to spellchecking.
# - K-gram index
# - weighted editorial distance
# - Norvig spellchecker
#
#
# # 1. [60] Building inverted index and answering queries
#
# ## 1.1. [10] Preprocessing
#
# First, we need a unified approach to documents preprocessing. Implement a class responsible for that. Complete the code for given functions (most of them are just one-liners) and make sure you pass the tests. Make use of `nltk` library or any other you know.

# %%
import nltk

class Preprocessor:
    
    def __init__(self):
        self.stop_words = {'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from', 'has', 'he', 'in', 'is', 'it', 'its',
                      'of', 'on', 'that', 'the', 'to', 'was', 'were', 'will', 'with'}
        self.ps = nltk.stem.PorterStemmer()

    
    def tokenize(self, text):
        #TODO word tokenize text using nltk lib
        return nltk.tokenize.word_tokenize(text)        
        
    def stem(self, word, stemmer):
        #TODO stem word using provided stemmer
        return stemmer.stem(word)

    
    def is_apt_word(self, word):
        #TODO check if word is appropriate - not a stop word and isalpha, 
        # i.e consists of letters, not punctuation, numbers, dates
        return word.isalpha() and word not in self.stop_words

    def is_apt_word_without_stop_words(self, word):
        #TODO check if word is appropriate - not a stop word and isalpha, 
        # i.e consists of letters, not punctuation, numbers, dates
        return word.isalpha()
    
    def preprocess(self, text):
        #TODO combine all previous methods together: tokenize lowercased text 
        # and stem it, ignoring not appropriate words
        words = self.tokenize(text.lower())
        words = [self.stem(word, self.ps) for word in words]
        words = list(filter(self.is_apt_word, words))
        return words

# %% [markdown]
# ### 1.1.1. Tests

# %%
prep = Preprocessor()
text = 'To be, or not to be, that is the question'

assert prep.tokenize(text) == ['To', 'be', ',', 'or', 'not', 'to', 'be', ',', 'that', 'is', 'the', 'question']
assert prep.stem('retrieval', prep.ps) == 'retriev'
assert prep.is_apt_word('qwerty123') is False
assert prep.preprocess(text) == ['or', 'not', 'question']

# %% [markdown]
# ## 1.2. [35] Crawling and Indexing
#
# ### 1.2.1. [10] Base classes
#
# Here are some base classes you will need for writing an indexer. The code from the first lab's solution is given, still you need to change some of it, namely, the `parse` function (it is also possible to use your own implementation from the first homework, but make sure that it is correct). The reason is it always makes complete parsing, which we want to avoid when we only need links, for example, or a specific portion of text.

# %%
import requests
from urllib.parse import quote
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse
import os


class Document:

    def __init__(self, url):
        self.url = url
    
    def download(self):
        try:
            response = requests.get(self.url)
            if response.status_code == 200:
                self.content = response.content
                return True
            else:
                return False
        except:
            return False

    def persist(self, path):
        with open(os.path.join(path, quote(self.url).replace('/', '_')), 'wb') as f:
            f.write(self.content)


class HtmlDocument(Document):

    def normalize(self, href):
        if href is not None and href[:4] != 'http':
            href = urllib.parse.urljoin(self.url, href)
        #else:
        return href

    def parse(self, anchors=True, images=False, text=False, article=False):
        #TODO change this method
        
        def tag_visible(element):
            if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
                return False
            if isinstance(element, Comment):
                return False
            return True
        
        if self.download():
            model = BeautifulSoup(self.content)
            

            self.anchors = []
            if anchors:
                a = model.find_all('a')
                for anchor in a:
                    href = self.normalize(anchor.get('href'))
                    text = anchor.text
                    if href != None:
                        self.anchors.append((text, href))

            self.images = []
            if images:
                i = model.find_all('img')
                for img in i:
                    href = self.normalize(img.get('src'))
                    self.images.append(href)

            self.text = []
            if text:
                texts = model.findAll(text=True)
                visible_texts = list(filter(tag_visible, texts))
                self.text = u" ".join(t.strip() for t in visible_texts)
            
            # method for retrieving the text only from the article itself
            if article:
                visible_texts = ""
                if model.find('p', class_='Paragraph-paragraph-2Bgue ArticleBody-para-TD_9x'):
                    paragraphs = model.find_all('p', class_='Paragraph-paragraph-2Bgue ArticleBody-para-TD_9x')
                    for paragraph in paragraphs:
                        text = paragraph.getText()
                        visible_texts += text.strip() 
                self.text = visible_texts

# %% [markdown]
# ### 1.2.2. [20] Main class
#
# The main indexer logic is here. We organize it as a crawler generator that adds certain visited pages to inverted index and saves them on disk.
#
# - `crawl_generator_for_index` method crawles the given website doing BFS, starting from `source` within given `depth`. Considers only inner pages (of a form https://www.reuters.com/...) for visiting. To speed up, doesn't consider for visiting pages with content type other than html: '.pdf', '.mp3', '.avi', '.mp4', '.txt'. If encounters an article page (of a form https://www.reuters.com/article/...), saves its content in a file in `collection_path` folder and populates the inverted index calling `index_doc` method. When done, saves on disk three resulting dictionaries:
#     - `doc_urls`, `doc_id:url`
#     - `index`, `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#     - `doc_lengths`, `doc_id:doc_length`
#
#
#     `limit` parameter is given for testing - if not `None`, break the loop when number of saved articles exceeds the `limit` and return without writing dictionaries to disk.
#
#
# - `index_doc` method parses and preprocesses the content of a `doc` and adds it to the inverted index. Also keeps track of document lengths in a `doc_lengths` dictionary.
#
# Your crawler have to print visited urls as it runs.

# %%
from collections import Counter
from queue import Queue
import pickle
import os

class Indexer:

    def __init__(self):      
        # dictionaries to populate
        self.doc_urls = {}        
        self.index = {}
        self.doc_lengths = {}
        # preprocessor
        self.prep = Preprocessor()
        
    
    def crawl_generator_for_index(self, source, depth, collection_path="collection", limit=None):        
        #TODO generate url-s for visiting
        
        if not os.path.exists(collection_path):
            os.makedirs(collection_path)

        article_counter = 0
        ignore_extension = ['pdf', 'mp3', 'avi', 'mp4', 'txt']
        
        self.doc_data = HtmlDocument(source)
        self.doc_data.parse(images=False)
        
        processed = set()
        processed.add(source)
        
        q = Queue()
        for anchor in self.doc_data.anchors:
            
            if anchor[1].startswith("https://www.reuters.com") and anchor[1].split(".")[-1] not in ignore_extension:

                q.put([anchor[1], 1])

        yield self.doc_data
        
        while not q.empty() and (limit == None or article_counter < limit):
            new_url = q.get()
                
            if new_url[0] not in processed and new_url[1] < depth:
    
                try:
                    self.doc_data = HtmlDocument(new_url[0])
                
                    if len(new_url[0].split("/")) > 3 and new_url[0].split("/")[3] == "article":
                        self.doc_data.parse(article=True)
                        self.doc_data.persist(collection_path)
                        self.index_doc(self.doc_data, len(self.doc_urls))
                        article_counter += 1
                    else:
                        self.doc_data.parse()
                    

                    for anchor in self.doc_data.anchors:
                        
                        if anchor[1] not in processed and anchor[1].startswith("https://www.reuters.com") \
                        and anchor[1].split(".")[-1] not in ignore_extension:
                            q.put([anchor[1], new_url[1] + 1])
                    
                    processed.add(new_url[0])
                    yield self.doc_data
                    
                except Exception as e:
                    processed.add(new_url[0])

        # save results for later use
        with open('doc_urls.p', 'wb') as fp:
            pickle.dump(self.doc_urls, fp, protocol=pickle.HIGHEST_PROTOCOL)
        with open('inverted_index.p', 'wb') as fp:
            pickle.dump(self.index, fp, protocol=pickle.HIGHEST_PROTOCOL)
        with open('doc_lengths.p', 'wb') as fp:
            pickle.dump(self.doc_lengths, fp, protocol=pickle.HIGHEST_PROTOCOL)
    
        
    def index_doc(self, doc, doc_id):
        self.doc_urls[doc_id] = doc.url
        self.doc_lengths[doc_id] = len(self.prep.preprocess(doc.text))
        
        for term in self.prep.preprocess(doc.text):
            if term not in self.index:
                self.index[term] = [1, (doc_id, 1)]
            else:
                self.index[term][0] += 1
                doc_ids = list(map(lambda x: x[0], self.index[term][1:]))

                if doc_id in doc_ids:
                    idx = doc_ids.index(doc_id)
                    freq = self.index[term][idx+1][1]
                    self.index[term][idx+1] = (doc_id, freq+1)
                else:
                    self.index[term].append((doc_id, 1))

# %% [markdown]
# ### 1.2.3. Tests
#
# Please make sure your crawler prints out urls with `print(k, c.url)`

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/technology", 2, "test_collection", 5):
    print(k, c.url)
    k += 1

assert type(indexer.index) is dict
assert type(indexer.index['reuter']) is list
assert type(indexer.index['reuter'][0]) is int
assert type(indexer.index['reuter'][1]) is tuple
# Out:
# 1 https://www.reuters.com/technology
# 2 https://www.reuters.com/
# 3 https://www.reuters.com/home
# 4 https://www.reuters.com/world
# 5 https://www.reuters.com/world/us-politics
# 6 https://www.reuters.com/world/us
# 7 https://www.reuters.com/world/uk
# 8 https://www.reuters.com/world/china
# 9 https://www.reuters.com/world/india
# 10 https://www.reuters.com/world/americas
# 11 https://www.reuters.com/world/asia-pacific
# 12 https://www.reuters.com/world/europe
# 13 https://www.reuters.com/world/middle-east-africa
# 14 https://www.reuters.com/world/the-great-reboot
# 15 https://www.reuters.com/business
# 16 https://www.reuters.com/business/sustainable-business
# 17 https://www.reuters.com/business/legal
# 18 https://www.reuters.com/business/energy
# 19 https://www.reuters.com/business/environment
# 20 https://www.reuters.com/business/finance
# 21 https://www.reuters.com/business/media-telecom
# 22 https://www.reuters.com/business/healthcare-pharmaceuticals
# 23 https://www.reuters.com/business/autos-transportation
# 24 https://www.reuters.com/business/aerospace-defense
# 25 https://www.reuters.com/business/change-suite
# 26 https://www.reuters.com/business/retail-consumer
# 27 https://www.reuters.com/business/reuters-next
# 28 https://www.reuters.com/business/take-five
# 29 https://www.reuters.com/markets
# 30 https://www.reuters.com/markets/us
# 31 https://www.reuters.com/markets/europe
# 32 https://www.reuters.com/markets/asia
# 33 https://www.reuters.com/markets/deals
# 34 https://www.reuters.com/markets/global-market-data
# 35 https://www.reuters.com/markets/stocks
# 36 https://www.reuters.com/markets/bonds
# 37 https://www.reuters.com/markets/funds
# 38 https://www.reuters.com/markets/commodities
# 39 https://www.reuters.com/markets/currencies
# 40 https://www.reuters.com/breakingviews
# 41 https://www.reuters.com/investigates/
# 42 https://www.reuters.com/lifestyle
# 43 https://www.reuters.com/lifestyle/sports
# 44 https://www.reuters.com/lifestyle/science
# 45 https://www.reuters.com/lifestyle/wealth
# 46 https://www.reuters.com/lifestyle/oddly-enough
# 47 https://www.reuters.com/pictures
# 48 https://www.reuters.com/video
# 49 https://www.reuters.com
# 50 https://www.reuters.com/article/us-usa-huawei-tech-hong-kong/hsbc-and-huawei-cfo-reach-agreement-on-document-publication-linked-to-extradition-case-idUSKBN2BZ09H
# 51 https://www.reuters.com/article/us-china-tech-exchanges-analysis/analysis-chinese-tech-start-ups-pull-ipo-plans-as-beijing-tightens-scrutiny-idUSKBN2BY0UL
# 52 https://www.reuters.com/article/us-china-alibaba/alibaba-says-does-not-expect-material-impact-from-antitrust-fine-shares-rally-idUSKBN2BZ01P
# 53 https://www.reuters.com/article/us-tech-antitrust-apple/apple-agrees-to-testify-before-u-s-senate-on-app-store-antitrust-concerns-idUSKBN2BY0T8
# 54 https://www.reuters.com/article/us-singapore-robot-delivery/run-out-of-milk-robots-on-call-for-singapore-home-deliveries-idUSKBN2BZ02S

# %% [markdown]
# ### 1.2.4. Building an index

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/", 3, "docs_collection"):
    print(k, c.url)
    k += 1
# Out:
# 1 https://www.reuters.com/
# 2 https://www.reuters.com/home
# 3 https://www.reuters.com/world
# 4 https://www.reuters.com/world/us-politics
# 5 https://www.reuters.com/world/us
# 6 https://www.reuters.com/world/uk
# 7 https://www.reuters.com/world/china
# 8 https://www.reuters.com/world/india
# 9 https://www.reuters.com/world/americas
# 10 https://www.reuters.com/world/asia-pacific
# 11 https://www.reuters.com/world/europe
# 12 https://www.reuters.com/world/middle-east-africa
# 13 https://www.reuters.com/world/the-great-reboot
# 14 https://www.reuters.com/business
# 15 https://www.reuters.com/business/sustainable-business
# 16 https://www.reuters.com/business/legal
# 17 https://www.reuters.com/business/energy
# 18 https://www.reuters.com/business/environment
# 19 https://www.reuters.com/business/finance
# 20 https://www.reuters.com/business/media-telecom
# 21 https://www.reuters.com/business/healthcare-pharmaceuticals
# 22 https://www.reuters.com/business/autos-transportation
# 23 https://www.reuters.com/business/aerospace-defense
# 24 https://www.reuters.com/business/change-suite
# 25 https://www.reuters.com/business/retail-consumer
# 26 https://www.reuters.com/business/reuters-next
# 27 https://www.reuters.com/business/take-five
# 28 https://www.reuters.com/markets
# 29 https://www.reuters.com/markets/us
# 30 https://www.reuters.com/markets/europe
# 31 https://www.reuters.com/markets/asia
# 32 https://www.reuters.com/markets/deals
# 33 https://www.reuters.com/markets/global-market-data
# 34 https://www.reuters.com/markets/stocks
# 35 https://www.reuters.com/markets/bonds
# 36 https://www.reuters.com/markets/funds
# 37 https://www.reuters.com/markets/commodities
# 38 https://www.reuters.com/markets/currencies
# 39 https://www.reuters.com/breakingviews
# 40 https://www.reuters.com/technology
# 41 https://www.reuters.com/investigates/
# 42 https://www.reuters.com/lifestyle
# 43 https://www.reuters.com/lifestyle/sports
# 44 https://www.reuters.com/lifestyle/science
# 45 https://www.reuters.com/lifestyle/wealth
# 46 https://www.reuters.com/lifestyle/oddly-enough
# 47 https://www.reuters.com/pictures
# 48 https://www.reuters.com/video
# 49 https://www.reuters.com
# 50 https://www.reuters.com/article/us-health-coronavirus-vaccine-china/china-considers-mixing-covid-19-vaccines-to-boost-protection-rate-idUSKBN2BY0H1
# 51 https://www.reuters.com/article/us-health-coronavirus-sinovac-chile/the-right-path-chile-defends-sinovac-use-amid-fresh-efficacy-questions-idUSKBN2BY0SH
# 52 https://www.reuters.com/article/us-health-coronavirus-blinken/top-u-s-diplomat-criticizes-china-says-need-to-get-to-the-bottom-of-covid-19-origin-idUSKBN2BY0OQ
# 53 https://www.reuters.com/article/us-usa-minnesota-shooting/police-fatally-shoot-black-man-in-traffic-stop-near-minneapolis-protests-erupt-idUSKBN2BZ05U
# 54 https://www.reuters.com/article/us-china-alibaba/alibaba-says-does-not-expect-material-impact-from-antitrust-fine-shares-rally-idUSKBN2BZ01P
# 55 https://www.reuters.com/article/us-usa-georgia-voting-companies/corporate-leaders-plan-new-push-on-u-s-voting-rights-will-reconsider-campaign-donations-idUSKBN2BZ00T
# 56 https://www.reuters.com/article/us-peru-election/peru-fast-count-predicts-run-off-between-leftist-castillo-and-conservative-fujimori-idUSKBN2BW27K
# 57 https://www.reuters.com/theWire
# 58 https://www.reuters.com/article/us-global-markets/asia-shares-anxious-for-earnings-season-u-s-data-deluge-idUSKBN2BZ00Y?il=0
# 59 https://www.reuters.com/article/us-autos-southkorea-shares/shares-in-sk-innovation-surge-after-settlement-with-rival-brightens-u-s-prospects-idUSKBN2BZ00N?il=0
# 60 https://www.reuters.com/article/us-health-coronavirus-india/india-overtakes-brazil-as-worlds-second-worst-hit-country-by-covid-19-idUSKBN2BZ0A1?il=0
# 61 https://www.reuters.com/article/us-peru-election/peru-fast-count-predicts-run-off-between-leftist-castillo-and-conservative-fujimori-idUSKBN2BW27K?il=0
# 62 https://www.reuters.com/article/us-autos-europe-regulations-insight/once-green-plug-in-hybrid-cars-suddenly-look-like-dinosaurs-in-europe-idUSKBN2BZ0C2?il=0
# 63 https://www.reuters.com/article/us-usa-bonds-supply/analysis-big-u-s-treasury-auctions-could-restart-rise-in-yields-idUSKBN2BZ0C0?il=0
# 64 https://www.reuters.com/article/us-health-coronavirus-japan/japan-begins-covid-19-shots-for-over-65s-as-fourth-infection-wave-looms-idUSKBN2BZ0AE?il=0
# 65 https://www.reuters.com/article/us-peru-elections/leftist-candidate-pedro-castillo-leading-peruvian-elections-first-official-count-idUSKBN2BZ0B0?il=0
# 66 https://www.reuters.com/article/us-singapore-robot-delivery/run-out-of-milk-robots-on-call-for-singapore-home-deliveries-idUSKBN2BZ02S?il=0
# 67 https://www.reuters.com/article/us-peru-election/far-left-candidate-pedro-castillo-leads-peruvian-presidential-race-ipsos-fast-count-idUSKBN2BZ09P?il=0
# 68 https://www.reuters.com/article/us-ecuador-election/lasso-wins-ecuador-presidency-in-upset-over-socialist-rival-idUSKBN2BY049?il=0
# 69 https://www.reuters.com/article/us-usa-huawei-tech-hong-kong/hsbc-and-huawei-cfo-reach-agreement-on-document-publication-linked-to-extradition-case-idUSKBN2BZ09H?il=0
# 70 https://www.reuters.com/article/us-china-alibaba/alibaba-says-does-not-expect-material-impact-from-antitrust-fine-shares-rally-idUSKBN2BZ01P?il=0
# 71 https://www.reuters.com/article/us-health-coronavirus-vaccine-china/china-considers-mixing-covid-19-vaccines-to-boost-protection-rate-idUSKBN2BY0H1?il=0
# 72 https://www.reuters.com/article/us-usa-georgia-voting-companies/corporate-leaders-plan-new-push-on-u-s-voting-rights-will-reconsider-campaign-donations-idUSKBN2BZ00T?il=0
# 73 https://www.reuters.com/article/us-cambodia-khmer-rouge-photos/after-outcry-vice-removes-images-adding-smiles-to-khmer-rouge-victims-idUSKBN2BY0EO?il=0
# 74 https://www.reuters.com/article/us-newzealand-economy-rbnz/nzs-cenbank-to-stand-pat-as-it-assesses-travel-resumption-property-curbs-reuters-poll-idUSKBN2BZ04S?il=0
# 75 https://www.reuters.com/article/us-usa-taiwan/blinken-warns-of-chinas-increasingly-aggressive-actions-against-taiwan-idUSKBN2BY0GO?il=0
# 76 https://www.reuters.com/article/us-japan-economy-prices/japan-wholesale-prices-rise-for-first-time-in-13-months-as-global-recovery-boosts-commodity-costs-idUSKBN2BZ049?il=0
# 77 https://www.reuters.com/article/us-global-forex/dollar-pinned-down-by-lower-u-s-yields-inflation-data-in-focus-idUSKBN2BZ044?il=0
# 78 https://www.reuters.com/article/us-health-coronavirus-india/india-overtakes-brazil-as-worlds-second-worst-hit-country-by-covid-19-idUSKBN2BZ0A1
# 79 https://www.reuters.com/article/us-health-coronavirus-japan/japan-begins-covid-19-shots-for-over-65s-as-fourth-infection-wave-looms-idUSKBN2BZ0AE
# 80 https://www.reuters.com/article/us-health-coronavirus-australia/australia-abandons-covid-19-vaccination-targets-after-new-advice-on-astrazeneca-shots-idUSKBN2BY0UY
# 81 https://www.reuters.com/article/us-autos-europe-regulations-insight/once-green-plug-in-hybrid-cars-suddenly-look-like-dinosaurs-in-europe-idUSKBN2BZ0C2
# 82 https://www.reuters.com/article/singapore-robot-delivery/run-out-of-milk-robots-on-call-for-singapore-home-deliveries-idUSL4N2M22D1
# 83 https://www.reuters.com/article/us-golf-masters/golf-japans-matsuyama-hangs-on-to-make-history-with-masters-win-idUSKBN2BY0KV
# 84 https://www.reuters.com/news/entertainment
# 85 https://www.reuters.com/article/us-awards-bafta/recession-drama-nomadland-wins-best-film-at-bafta-awards-idUSKBN2BY0PY
# 86 https://www.reuters.com/article/us-awards-bafta-factbox/factbox-winners-of-the-2021-bafta-film-awards-idUSKBN2BY0Q6
# 87 https://www.reuters.com/article/us-global-markets/asia-shares-anxious-for-earnings-season-u-s-data-deluge-idUSKBN2BZ00Y
# 88 https://www.reuters.com/article/us-usa-fed-powell/feds-powell-u-s-economy-at-an-inflection-point-cbs-60-minutes-idUSKBN2BY0HS
# 89 https://www.reuters.com/article/us-southkorea-politics/my-romance-your-adultery-south-koreans-sarcasm-over-hypocrisy-follows-moon-into-final-year-idUSKBN2BW1JQ
# 90 https://www.reuters.com/article/us-iran-nuclear-natanz/iran-says-natanz-nuclear-site-hit-by-terrorism-tv-idUSKBN2BY052
# 91 https://www.reuters.com/article/us-usa-huawei-tech-hong-kong/hsbc-and-huawei-cfo-reach-agreement-on-document-publication-linked-to-extradition-case-idUSKBN2BZ09H
# 92 https://www.reuters.com/article/us-religion-ramadan-pakistan-lgbt/pakistani-transgender-woman-finds-a-niche-in-tailoring-idUSKBN2BZ038
# 93 https://www.reuters.com/news/pictures
# 94 https://www.reuters.com/news/picture/protests-erupt-after-black-man-shot-dead-idUSRTXBEDJE
# 95 https://www.reuters.com/news/picture/photos-of-the-week-idUSRTXBCF81
# 96 https://www.reuters.com/finance
# 97 https://www.reuters.com/article/us-autos-southkorea-shares/shares-in-sk-innovation-surge-after-settlement-with-rival-brightens-u-s-prospects-idUSKBN2BZ00N
# 98 https://www.reuters.com/article/us-usa-sec-esg/u-s-sec-review-of-socially-responsible-funds-finds-potentially-misleading-claims-idUSKBN2BW2SZ
# 99 https://www.reuters.com/article/us-usa-bonds-supply/analysis-big-u-s-treasury-auctions-could-restart-rise-in-yields-idUSKBN2BZ0C0
# 100 https://www.reuters.com/article/us-newzealand-economy-rbnz/nzs-cenbank-to-stand-pat-as-it-assesses-travel-resumption-property-curbs-reuters-poll-idUSKBN2BZ04S
# 101 https://www.reuters.com/article/us-japan-economy-prices/japan-wholesale-prices-rise-for-first-time-in-13-months-as-global-recovery-boosts-commodity-costs-idUSKBN2BZ049
# 102 https://www.reuters.com/article/us-peru-elections/leftist-candidate-pedro-castillo-leading-peruvian-elections-first-official-count-idUSKBN2BZ0B0
# 103 https://www.reuters.com/article/us-peru-election/far-left-candidate-pedro-castillo-leads-peruvian-presidential-race-ipsos-fast-count-idUSKBN2BZ09P
# 104 https://www.reuters.com/article/us-ecuador-election/lasso-wins-ecuador-presidency-in-upset-over-socialist-rival-idUSKBN2BY049
# 105 https://www.reuters.com/article/us-singapore-robot-delivery/run-out-of-milk-robots-on-call-for-singapore-home-deliveries-idUSKBN2BZ02S
# 106 https://www.reuters.com/article/us-china-tech-exchanges-analysis/analysis-chinese-tech-start-ups-pull-ipo-plans-as-beijing-tightens-scrutiny-idUSKBN2BY0UL
# 107 https://www.reuters.com/article/us-tech-antitrust-apple/apple-agrees-to-testify-before-u-s-senate-on-app-store-antitrust-concerns-idUSKBN2BY0T8
# 108 https://www.reuters.com/politics
# 109 https://www.reuters.com/article/us-usa-trump/trump-tells-republican-donors-hell-help-win-congress-in-2022-idUSKBN2BY00H
# 110 https://www.reuters.com/article/us-usa-congress-crenshaw/former-u-s-navy-seal-to-take-leave-from-congress-after-eye-surgery-idUSKBN2BX0G4
# 111 https://www.reuters.com/article/us-usa-biden-budget/bidens-budget-meets-criticism-from-right-and-left-on-pentagon-spending-idUSKBN2BW190
# 112 https://www.reuters.com/article/us-cmoc-catl-mine/catl-takes-stake-in-china-moly-cobalt-mine-for-137-5-million-idUSKBN2BY0BZ
# 113 https://www.reuters.com/article/us-ingersoll-ran-m-a-platinum-club-car-e/exclusive-ingersoll-rand-nears-1-7-billion-deal-to-sell-golf-cart-business-to-platinum-equity-sources-idUSKBN2BY0TJ
# 114 https://www.reuters.com/article/us-luminex-m-a-diasorin/italian-diagnostics-group-diasorin-to-buy-luminex-for-1-8-billion-idUSKBN2BY0R2
# 115 https://www.reuters.com/investigates/special-report/tips/
# 116 https://www.reuters.com/tools/podcasts
# 117 https://www.reuters.com/tools/mobile
# 118 https://www.reuters.com/fact-check
# 119 https://www.reuters.com/info/disclaimer
# 120 https://www.reuters.com/advertising-guidelines
# 121 https://www.reuters.com/terms-of-use
# 122 https://www.reuters.com/article/us-health-coronavirus-venezuela-vaccines/maduro-says-venezuela-has-secured-funds-to-complete-covax-payment-idUSKBN2BZ0EN
# 123 https://www.reuters.com/article/us-britain-royals-philip/weve-lost-the-grandfather-of-the-nation-uks-prince-andrew-says-idUSKBN2BY0C5
# 124 https://www.reuters.com/article/us-health-coronavirus-britain/english-shops-and-pub-gardens-reopen-in-major-step-to-freedom-idUSKBN2BY0RW
# 125 https://www.reuters.com/article/us-health-coronavirus-brazil/brazil-sees-1803-covid-19-deaths-chinese-vaccine-found-50-7-effective-against-variant-idUSKBN2BY0T2
# 126 https://www.reuters.com/news/archive/worldnews?view=page&page=2&pageSize=10
# 127 https://www.reuters.com/video/2021/04/11/china-considers-mixing-covid-19-vaccines?videoId=728351728&videoChannel=117760
# 128 https://www.reuters.com/video/2021/04/11/greenpeace-illegal-driftnet-use-in-india?videoId=728350058&videoChannel=117760
# 129 https://www.reuters.com/video/2021/04/11/special-service-held-for-prince-philip?videoId=728348873&videoChannel=117760
# 130 https://www.reuters.com/video/2021/04/11/benin-votes-for-president-after-week-of?videoId=728342888&videoChannel=117760
# 131 https://www.reuters.com/video/2021/04/11/ash-covered-streets-after-caribbean-volc?videoId=728333047&videoChannel=117760
# 132 https://www.reuters.com/article/us-usa-congress-gaetz/u-s-house-ethics-panel-launches-investigation-into-republican-gaetz-idUSKBN2BW1KF
# 133 https://www.reuters.com/article/us-usa-court-biden/biden-forms-panel-to-study-possible-u-s-supreme-court-expansion-idUSKBN2BW22G
# 134 https://www.reuters.com/article/us-usa-immigration-jacobson/white-house-border-coordinator-jacobson-leaving-role-at-end-of-april-idUSKBN2BW2PQ
# 135 https://www.reuters.com/article/us-usa-biden-budget-climate/biden-budgets-14-billion-hike-for-climate-includes-big-boosts-for-epa-science-idUSKBN2BW22C
# 136 https://www.reuters.com/article/us-usa-immigration-border-exclusive/exclusive-u-s-considering-cash-payments-to-central-america-to-stem-migration-idUSKBN2BW2L1
# 137 https://www.reuters.com/article/us-usa-biden-budget-immigration/biden-seeks-funding-to-probe-white-supremacist-beliefs-at-immigration-agencies-idUSKBN2BW21J
# 138 https://www.reuters.com/article/us-autos-electric-politics/biden-faces-key-test-on-ev-battery-trade-dispute-idUSKBN2BW19F
# 139 https://www.reuters.com/news/archive/politicsnews?view=page&page=2&pageSize=10
# 140 https://www.reuters.com/video/2021/04/07/wayne-lapierre-testifies-at-nra-bankrupt?videoId=728216738&videoChannel=1003
# 141 https://www.reuters.com/video/2021/04/09/bidens-2022-budget-marks-departure-from?videoId=728291297&videoChannel=1003
# 142 https://www.reuters.com/video/2021/04/09/us-should-always-have-the-best-infrastru?videoId=728288000&videoChannel=1003
# 143 https://www.reuters.com/video/2021/04/08/biden-announces-steps-to-limit-ghost-gun?videoId=728249590&videoChannel=1003
# 144 https://www.reuters.com/video/2021/04/07/biden-inaction-not-an-option-on-infrastr?videoId=728213652&videoChannel=1003
# 145 https://www.reuters.com/article/us-usa-race-georgefloyd-crump/this-is-their-blood-civil-rights-lawyer-crump-fights-for-george-floyds-family-idUSKBN2BY0C1
# 146 https://www.reuters.com/article/us-south-carolina-shooting/sixth-victim-dies-from-shooting-by-ex-nfl-player-in-south-carolina-home-idUSKBN2BY0IE
# 147 https://www.reuters.com/article/us-health-coronavirus-usa-justice/thousands-of-low-level-u-s-inmates-released-in-pandemic-could-be-headed-back-to-prison-idUSKBN2BY0AU
# 148 https://www.reuters.com/article/us-hawaii-shooting/armed-suspect-found-dead-after-10-hour-standoff-with-police-at-hawaii-hotel-report-idUSKBN2BY08K
# 149 https://www.reuters.com/article/us-health-coronavirus-usa-cdc/u-s-has-administered-187-million-doses-of-covid-19-vaccines-cdc-says-idUSKBN2BZ022
# 150 https://www.reuters.com/article/us-people-clark-obituary/ramsey-clark-former-u-s-attorney-general-and-human-rights-activist-dead-at-93-idUSKBN2BY01G
# 151 https://www.reuters.com/news/archive/domesticnews?view=page&page=2&pageSize=10
# 152 https://www.reuters.com/article/uk-health-coronavirus-britain/english-shops-and-pub-gardens-reopen-in-major-step-to-freedom-idUSKBN2BY0RU
# 153 https://www.reuters.com/article/uk-britain-royals-philip/weve-lost-the-grandfather-of-the-nation-uks-prince-andrew-says-idUSKBN2BY0BS
# 154 https://www.reuters.com/article/uk-health-coronavirus-britain-economy/confidence-among-uk-finance-chiefs-hits-record-high-deloitte-idUSKBN2BY0U0
# 155 https://www.reuters.com/article/uk-britain-eu-commission/uk-mps-business-figures-set-up-an-independent-commission-to-improve-brexit-trade-deal-ft-idUSKBN2BY0V0
# 156 https://www.reuters.com/article/uk-investors-slavery/uk-investors-expand-anti-slavery-push-to-construction-materials-sectors-idUSKBN2BY0TW
# 157 https://www.reuters.com/article/uk-health-coronavirus-britain-retail/after-dire-year-englands-shops-hope-for-end-of-lockdown-shopping-spree-idUSKBN2BY078
# 158 https://www.reuters.com/article/uk-awards-bafta/recession-drama-nomadland-wins-best-film-at-bafta-awards-idUSKBN2BY0PU
# 159 https://www.reuters.com/article/uk-ukraine-crisis-britain-usa/uk-and-usa-say-russia-must-de-escalate-situation-in-ukraine-uks-raab-idUSKBN2BY07Q
# 160 https://www.reuters.com/article/uk-soccer-england-tot-mun-report-wrapup/man-utd-beat-spurs-west-ham-maintain-top-four-charge-idUSKBN2BY0S3
# 161 https://www.reuters.com/article/uk-health-coronavirus-eu-astrazeneca/astrazeneca-says-it-had-positive-meeting-with-eu-over-vaccine-row-idUSKBN2BY0HG
# 162 https://www.reuters.com/news/archive/ukdomestic?view=page&page=2&pageSize=10
# 163 https://www.reuters.com/article/us-china-alibaba-breakingviews/breakingviews-fine-leaves-sharp-sword-hanging-over-alibaba-idUSKBN2BZ06U
# 164 https://www.reuters.com/article/us-china-alibaba-breakingviews/breakingviews-fine-leaves-sharp-sword-hanging-over-alibaba-idUSKBN2BZ06B
# 165 https://www.reuters.com/article/us-usa-taiwan/blinken-warns-of-chinas-increasingly-aggressive-actions-against-taiwan-idUSKBN2BY0GO
# 166 https://www.reuters.com/article/us-health-coronavirus-china-cases/mainland-china-reports-16-new-covid-19-cases-vs-10-a-day-earlier-idUSKBN2BY00T
# 167 https://www.reuters.com/article/us-china-tech-antitrust-regulator-exclus/exclusive-chinas-antitrust-regulator-bulking-up-as-crackdown-on-behemoths-widens-idUSKBN2BY0AC
# 168 https://www.reuters.com/article/us-china-alibaba-timeline/events-leading-up-to-chinas-2-75-billion-fine-on-alibaba-idUSKBN2BX04W
# 169 https://www.reuters.com/article/us-china-alibaba/china-fines-alibaba-record-2-75-billion-for-anti-monopoly-violations-idUSKBN2BX015
# 170 https://www.reuters.com/article/us-china-alibaba-jack-ma-newsmaker/record-penalty-for-mas-alibaba-marks-tumultuous-stretch-for-its-founder-idUSKBN2BY06F
# 171 https://www.reuters.com/article/us-myanmar-politics-eu/china-russia-undermine-international-myanmar-response-eus-top-diplomat-says-idUSKBN2BY0CO
# 172 https://www.reuters.com/article/us-china-accidents-mine/xinjiang-coalmine-accident-traps-21-china-state-media-idUSKBN2BY01K
# 173 https://www.reuters.com/article/us-philippines-usa-southchinasea/philippines-u-s-to-begin-2-week-joint-military-drill-on-monday-idUSKBN2BY07A
# 174 https://www.reuters.com/article/us-health-coronavirus-china-vaccine/china-administers-164-47-million-covid-19-vaccinations-as-of-april-10-idUSKBN2BY09L
# 175 https://www.reuters.com/article/us-china-cyberspace-history/china-launches-hotline-for-netizens-to-report-illegal-history-comments-idUSKBN2BY08Z
# 176 https://www.reuters.com/article/us-china-alibaba-instant-view/expert-view-chinas-alibaba-hit-with-record-2-75-billion-antitrust-fine-idUSKBN2BX029
# 177 https://www.reuters.com/news/archive/china-news?view=page&page=2&pageSize=10
# 178 https://www.reuters.com/article/india-stocks/indian-shares-plunge-as-raging-virus-threatens-economic-recovery-idUSKBN2BZ09M
# 179 https://www.reuters.com/article/health-coronavirus-india/india-overtakes-brazil-as-worlds-second-worst-hit-country-by-covid-19-idUSKBN2BZ09Z
# 180 https://www.reuters.com/article/environment-oceans/illegal-driftnet-use-widespread-in-indian-ocean-greenpeace-says-idUSKBN2BY05Z
# 181 https://www.reuters.com/article/health-coronavirus-india-remdesivir/india-bans-remdesivir-exports-as-coronavirus-rages-on-rallies-continue-idUSKBN2BY0EB
# 182 https://www.reuters.com/article/indonesia-quake/indonesian-president-orders-java-rescue-efforts-after-quake-kills-8-idUSKBN2BY0B5
# 183 https://www.reuters.com/article/health-coronavirus-india/indias-new-covid-19-cases-hit-record-again-amid-vaccination-push-idUSKBN2BY03P
# 184 https://www.reuters.com/article/health-coronavirus-south-asia-cases/south-asia-surpasses-grim-milestone-of-15-million-covid-19-cases-reuters-tally-idUSKBN2BX08G
# 185 https://www.reuters.com/article/india-usa/india-protests-u-s-navys-transit-through-its-exclusive-economic-zone-idUSKBN2BX07N
# 186 https://www.reuters.com/article/india-politics-election/poll-violence-kills-five-in-indias-battleground-state-bengal-idUSKBN2BX07B
# 187 https://www.reuters.com/article/health-coronavirus-india/indias-daily-covid-19-cases-rise-to-record-for-fifth-time-this-week-idUSKBN2BX02T
# 188 https://www.reuters.com/article/cricket-india-ipl/kohli-says-patel-has-ended-bangalores-death-overs-woes-idUSKBN2BX03X
# 189 https://www.reuters.com/news/archive/india-only?view=page&page=2&pageSize=10
# 190 https://www.reuters.com/article/us-health-coronavirus-snapshot/what-you-need-to-know-about-the-coronavirus-right-now-idUSKBN2BZ0CK
# 191 https://www.reuters.com/article/us-mining-copper-antofagasta/chiles-antofagasta-says-surging-copper-price-not-enough-to-entice-big-investments-idUSKBN2BZ05O
# 192 https://www.reuters.com/article/us-global-emissions-kemp/column-global-co2-emissions-far-off-net-zero-trajectory-idUSKBN2BW22O
# 193 https://www.reuters.com/article/us-caribbean-volcano/power-outages-hit-saint-vincent-island-amid-volcano-tremors-idUSKBN2BY0N0
# 194 https://www.reuters.com/article/us-health-coronavirus-canada-vaccine/in-covid-19-vaccination-pivot-canada-targets-frontline-workers-idUSKBN2BY0GC
# 195 https://www.reuters.com/article/us-telesat-cnda-satellite-race-focus/canadas-telesat-takes-on-musk-and-bezos-in-space-race-to-provide-fast-broadband-idUSKBN2BY0G0
# 196 https://www.reuters.com/article/us-caribbean-volcano/ash-coats-caribbean-island-of-saint-vincent-after-volcano-eruption-idUSKBN2BX0D1
# 197 https://www.reuters.com/article/us-health-coronavirus-mexico-tally/mexico-reports-2192-new-coronavirus-deaths-after-data-review-idUSKBN2BX0JS
# 198 https://www.reuters.com/article/us-health-coronavirus-peru/the-day-before-elections-peru-marks-record-covid-19-deaths-idUSKBN2BX0LS
# 199 https://www.reuters.com/article/us-peru-election-candidates/opus-dei-leftist-former-goalie-whos-who-in-peru-election-race-idUSKBN2BV1DK
# 200 https://www.reuters.com/article/us-health-coronavirus-chile-archbishop/archbishop-of-santiago-chile-hospitalized-after-testing-positive-for-covid-19-idUSKBN2BX0KN
# 201 https://www.reuters.com/news/archive/americas-news?view=page&page=2&pageSize=10
# 202 https://www.reuters.com/article/us-health-coronavirus-newzealand/new-zealands-ardern-says-border-workers-must-take-covid-19-vaccine-after-new-cases-idUSKBN2BZ0CE
# 203 https://www.reuters.com/article/us-health-coronavirus-thailand/thailand-reports-daily-record-of-985-new-coronavirus-cases-idUSKBN2BZ0AW
# 204 https://www.reuters.com/article/us-cambodia-khmer-rouge-photos/after-outcry-vice-removes-images-adding-smiles-to-khmer-rouge-victims-idUSKBN2BY0EO
# 205 https://www.reuters.com/article/us-australia-cyclone/cyclone-destroys-houses-cuts-power-on-australias-west-coast-idUSKBN2BZ06O
# 206 https://www.reuters.com/article/us-global-forex/dollar-pinned-down-by-lower-u-s-yields-inflation-data-in-focus-idUSKBN2BZ044
# 207 https://www.reuters.com/article/us-japan-economy-loans/japan-bank-lending-rises-again-as-pandemic-pressures-services-sector-idUSKBN2BZ01W
# 208 https://www.reuters.com/news/archive/rcom-apac?view=page&page=2&pageSize=10
# 209 https://www.reuters.com/article/us-britain-royals-philip-family/british-royals-react-to-prince-philips-death-idUSKBN2BY0LW
# 210 https://www.reuters.com/article/us-usa-diplomacy-blinken/blinken-to-return-to-brussels-for-talks-on-ukraine-afghanistan-idUSKBN2BY0MV
# 211 https://www.reuters.com/article/us-health-coronavirus-israel-study/south-african-variant-may-evade-protection-from-pfizer-vaccine-israeli-study-says-idUSKBN2BX0JZ
# 212 https://www.reuters.com/article/us-health-coronavirus-britain-cases/uk-nears-40-million-first-and-second-vaccine-doses-idUSKBN2BY0J8
# 213 https://www.reuters.com/article/us-autos-electric-politics/s-korean-battery-makers-agree-1-8-billion-settlement-aiding-bidens-ev-push-idUSKBN2BX0HI
# 214 https://www.reuters.com/article/us-germany-politics/factbox-bavarian-soeder-ready-to-run-for-german-chancellor-if-cdu-supports-him-idUSKBN2BY0GT
# 215 https://www.reuters.com/article/us-britain-royals-philip-bbc/too-much-prince-philip-coverage-bbc-says-complaints-have-been-received-idUSKBN2BX0D9
# 216 https://www.reuters.com/article/us-britain-royals-philip/prince-charles-pays-tribute-to-my-dear-papa-philip-for-devoted-service-idUSKBN2BX05M
# 217 https://www.reuters.com/article/us-autos-electric-politics-biden/biden-welcomes-settlement-between-south-korean-firms-on-electric-battery-dispute-idUSKBN2BY0DH
# 218 https://www.reuters.com/article/us-ukraine-crisis-turkey/turkeys-erdogan-calls-for-end-to-worrying-developments-in-eastern-ukraine-offers-support-idUSKBN2BX09A
# 219 https://www.reuters.com/article/us-britain-royals-philip-funeral/prince-philip-to-have-ceremonial-funeral-on-april-17-harry-to-attend-idUSKBN2BX0EH
# 220 https://www.reuters.com/article/us-ukraine-crisis-minister/ukraine-says-it-could-be-provoked-by-russian-aggression-in-conflict-area-idUSKBN2BX072
# 221 https://www.reuters.com/article/us-health-coronavirus-france-cases/french-coronavirus-intensive-care-cases-and-deaths-keep-rising-idUSKBN2BX0G6
# 222 https://www.reuters.com/article/us-britain-royals-philip-salutes/prince-philips-death-marked-by-gun-salutes-across-uk-idUSKBN2BX09E
# 223 https://www.reuters.com/article/us-portugal-corruption-socrates/portugal-ex-pm-socrates-to-face-trial-for-alleged-money-laundering-graft-charges-dropped-idUSKBN2BW29C
# 224 https://www.reuters.com/article/us-britain-nireland-loyalists/northern-irish-loyalists-demand-brexit-changes-call-for-end-to-street-violence-idUSKBN2BW20Y
# 225 https://www.reuters.com/news/archive/rcom-europe?view=page&page=2&pageSize=10
# 226 https://www.reuters.com/article/us-jordan-security-royals-rift/jordans-king-abdullah-and-estranged-prince-hamza-make-first-joint-appearance-since-rift-idUSKBN2BY0CE
# 227 https://www.reuters.com/article/us-emirates-space/uae-selects-first-arab-woman-for-astronaut-training-idUSKBN2BY097
# 228 https://www.reuters.com/article/us-libya-security-turkey/libyas-new-pm-to-visit-turkey-hold-talks-with-erdogan-on-monday-idUSKBN2BY0H8
# 229 https://www.reuters.com/article/us-usa-israel-austin/israel-pledges-to-work-with-u-s-on-iran-idUSKBN2BY05X
# 230 https://www.reuters.com/article/us-ethiopia-dam-egypt-sudan/egypt-sudan-reject-ethiopian-proposal-for-data-sharing-on-renaissance-dam-idUSKBN2BX0KV
# 231 https://www.reuters.com/article/us-iran-nuclear/iran-launches-advanced-uranium-enriching-machines-to-mark-nuclear-day-idUSKBN2BX09K
# 232 https://www.reuters.com/article/us-lebanon-crisis-port/let-us-rebuild-beiruts-port-in-less-than-three-years-says-frances-cma-cgm-idUSKBN2BX0BK
# 233 https://www.reuters.com/news/archive/middle-east?view=page&page=2&pageSize=10
# 234 https://www.reuters.com/article/us-health-coronavirus-greece-digitalnoma/sun-sea-and-cybernauts-the-long-road-for-greeces-digital-nomads-idUSKBN2BU19T
# 235 https://www.reuters.com/article/us-money-women-breadwinners/how-to-think-like-a-breadwinner-idUSKBN2BZ0BM
# 236 https://www.reuters.com/article/us-health-coronavirus-britain-economy/confidence-among-uk-finance-chiefs-hits-record-high-deloitte-idUSKBN2BY0UJ
# 237 https://www.reuters.com/article/us-amazon-com-union-labor-defeat-analysi/analysis-amazons-win-in-union-fight-shows-harsh-realities-facing-labor-movement-idUSKBN2BW2CX
# 238 https://www.reuters.com/article/us-hsbc-working-from-home-exclusive/exclusive-hsbc-moves-more-than-1200-uk-staff-to-permanent-home-working-idUSKBN2BU1PK
# 239 https://www.reuters.com/article/us-health-coronavirus-france-airport/eerily-silent-paris-cdg-marks-easter-without-air-travel-rush-idUSKBN2BP16A
# 240 https://www.reuters.com/article/us-retailers-spring-fashion/fashion-retailers-bet-bras-with-wires-and-a-splash-of-color-will-sell-this-spring-idUSKBN2BO501
# 241 https://www.reuters.com/video/2021/03/17/x-rated-xr-developed-for-post-pandemic-i?videoId=727355723&videoChannel=118314
# 242 https://www.reuters.com/video/2021/02/10/this-dubai-cafe-is-staffed-entirely-by-r?videoId=725638680&videoChannel=118314
# 243 https://www.reuters.com/video/2021/02/09/what-tokyo-2020-organizers-could-learn-f?videoId=725630345&videoChannel=118314
# 244 https://www.reuters.com/article/us-global-tax-breakingviews/breakingviews-review-taxs-weird-past-exposes-present-oddities-idUSKBN2BW1GR
# 245 https://www.reuters.com/article/us-global-finance-breakingviews/breakingviews-capital-calls-vaccine-startups-u-s-ipo-dents-uk-ambitions-idUSKBN2BV27I
# 246 https://www.reuters.com/article/us-global-finance-breakingviews/breakingviews-capital-calls-macron-sacrifices-elite-narques-idUSKBN2BV24I
# 247 https://www.reuters.com/article/us-fast-food-delivery-crispy/crunch-time-fast-food-chains-look-to-keep-food-crisp-as-deliveries-soar-idUSKBN2BN1CX
# 248 https://www.reuters.com/article/us-eurozone-usa-divergence-graphic/real-economy-stirrings-show-u-s-leaves-europe-in-the-dust-idUSKBN2BM0H1
# 249 https://www.reuters.com/article/us-usa-economy-wealth/gen-x-emerging-from-pandemic-with-firmer-grip-on-americas-wallet-idUSKBN2BL1BL
# 250 https://www.reuters.com/article/us-health-coronavirus-singapore-event/singapore-tests-distancing-dongles-to-track-mingling-at-meetings-idUSKBN2BG1HJ
# 251 https://www.reuters.com/article/us-canada-economy-spending-analysis/analysis-pools-and-bucket-list-trips-canadians-itching-to-spend-pandemic-nest-eggs-idUSKBN2BG1A0
# 252 https://www.reuters.com/article/us-health-coronavirus-art-market-analysi/analysis-one-year-into-pandemic-the-art-world-adapts-to-survive-idUSKBN2BA17E
# 253 https://www.reuters.com/news/archive/greatreboot?view=page&page=2&pageSize=10
# 254 https://www.reuters.com/world/the-great-reboot/article/idUSRTX7XPL8
# 255 https://www.reuters.com/video/2021/04/10/alibaba-fined-275b-by-chinese-regulators?videoId=728302620&videoChannel=5
# 256 https://www.reuters.com/video/2021/04/09/record-close-for-dow-sp-500?videoId=728293114&videoChannel=5
# 257 https://www.reuters.com/video/2021/04/09/amazoncom-workers-reject-forming-union?videoId=728289326&videoChannel=5
# 258 https://www.reuters.com/news/archive/businessnews?view=page&page=2&pageSize=10
# 259 https://www.reuters.com/finance/markets
# 260 https://www.reuters.com/finance/markets/index?symbol=.SPX
# 261 https://www.reuters.com/finance/markets/index?symbol=.DJI
# 262 https://www.reuters.com/finance/markets/index?symbol=.FTSE
# 263 https://www.reuters.com/finance/markets/index?symbol=.N225
# 264 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=EUR
# 265 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=GBP
# 266 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=JPY
# 267 https://www.reuters.com/article/us-eu-autos/most-european-city-dwellers-support-2030-ban-on-combustion-car-sales-survey-finds-idUSKBN2BY0SK
# 268 https://www.reuters.com/article/us-facebook-advertising/study-flags-gender-bias-in-facebooks-ads-tools-idUSKBN2BW1LG
# 269 https://www.reuters.com/video/?chan=9hh451f6
# 270 https://www.reuters.com/video/2021/04/08/cashing-in-on-chinas-carbon-neutral-driv?videoId=728227682&videoChannel=118285
# 271 https://www.reuters.com/video/2021/04/07/explainer-what-is-a-global-minimum-tax?videoId=728196572&videoChannel=118285
# 272 https://www.reuters.com/video/2021/04/07/digital-nomads-wooed-by-greece?videoId=728196782&videoChannel=118285
# 273 https://www.reuters.com/subjects/sustainable-business/environmental-impact
# 274 https://www.reuters.com/article/us-norway-swf/norway-wealth-fund-should-invest-in-fewer-companies-government-says-idUSKBN2BW2TC
# 275 https://www.reuters.com/article/us-usa-pipeline-dakota-access/u-s-army-corps-allows-dakota-access-pipeline-to-stay-open-during-review-idUSKBN2BW0E9
# 276 https://www.reuters.com/subjects/sustainable-business/workplace-equality
# 277 https://www.reuters.com/article/us-japan-boj-diversity/japans-male-dominated-central-bank-sets-new-diversity-target-idUSKBN2BF1CR
# 278 https://www.reuters.com/article/us-blackrock-diversity/blackrock-hires-law-firm-for-internal-review-after-latest-executive-conduct-complaints-idUSKBN2BF00F
# 279 https://www.reuters.com/article/us-britain-finance-women/some-uk-financial-firms-blame-covid-for-missing-target-of-women-in-senior-roles-idUSKBN2B90YV
# 280 https://www.reuters.com/subjects/sustainable-business/tech-trust
# 281 https://www.reuters.com/article/us-eu-tech/europe-seeks-semiconductor-boost-first-quantum-computer-idUSKBN2B02D4
# 282 https://www.reuters.com/article/us-uber-electric-vehicles/uber-expands-green-trip-option-to-over-1400-cities-in-north-america-idUSKBN29H1ZT
# 283 https://www.reuters.com/article/us-twitter-content-hate/twitter-expands-hate-speech-rules-to-include-race-ethnicity-idUSKBN28D03U
# 284 https://www.reuters.com/subjects/sustainable-business/responsible-investing
# 285 https://www.reuters.com/article/us-bank-of-america-esg/bank-of-america-to-deploy-1-trillion-for-sustainable-finance-by-2030-idUSKBN2BV29W
# 286 https://www.reuters.com/article/uk-climate-change-ecb/big-ecb-climate-change-role-may-be-step-too-far-warns-wunsch-idUSKBN2BT1QW
# 287 https://www.reuters.com/article/us-climate-change-central-banks/china-and-brazil-have-worlds-greenest-central-banks-activists-say-idUSKBN2BN01K
# 288 https://www.reuters.com/article/us-jp-morgan-esg/jpmorgan-forms-new-team-in-commercial-banking-unit-as-part-of-green-push-idUSKBN2BV28J
# 289 https://www.reuters.com/article/us-norilsknickel-dividend/nornickel-considers-2-billion-buyback-in-compensation-for-lower-dividend-idUSKBN2BW2UT
# 290 https://www.reuters.com/news/archive/esgnews?view=page&page=2&pageSize=10
# 291 https://www.reuters.com/news/archive/esg
# 292 https://www.reuters.com/article/knight-merger/holland-knight-tie-up-may-usher-in-the-next-wave-of-big-law-mergers-idUSL1N2M2372
# 293 https://www.reuters.com/article/lawyer-merge-holland/holland-knight-and-thompson-knight-in-merger-talks-idUSL1N2M228W
# 294 https://www.reuters.com/article/idUSKBN2BW22G
# 295 https://www.reuters.com/article/us-amazon-com-union-legislation/failed-amazon-union-effort-renews-call-for-updated-u-s-labor-laws-idUSKBN2BW2I6?il=0
# 296 https://www.reuters.com/article/us-amazon-com-new-york-lawsuits/judge-hands-amazon-a-setback-in-new-york-lawsuit-over-covid-19-shortfalls-idUSKBN2BW2TW
# 297 https://www.reuters.com/article/us-credit-suisse-data-breach/credit-suisses-u-s-brokerage-files-lawsuit-over-personal-data-leak-idUSKBN2BW2ET
# 298 https://www.reuters.com/article/us-citigroup-revlon-lawsuit/citigroup-lawyer-says-another-bank-made-bigger-payment-error-than-revlon-idUSKBN2AV1WS
# 299 https://www.reuters.com/article/us-usa-race-georgefloyd/doctor-who-performed-george-floyd-autopsy-stands-by-homicide-conclusion-idUSKBN2BW26K
# 300 https://www.reuters.com/article/us-amazon-com-union-ballots-exclusive/exclusive-roughly-500-ballots-challenged-in-amazons-landmark-union-election-idUSKBN2BW084
# 301 https://www.reuters.com/article/us-boeing-air-force/boeing-sues-cancels-contracts-with-air-force-one-supplier-idUSKBN2BV37Z
# 302 https://www.reuters.com/news/archive/westLaw
# 303 https://www.reuters.com/article/lawyer-cannabis-deals/goodwin-venable-straddle-two-burning-trends-in-billion-dollar-cannabis-spac-deal-idUSL1N2M235N
# 304 https://www.reuters.com/article/immigration-visas/biden-administration-sued-for-refusing-to-issue-visas-amid-covid-travel-bans-idUSL1N2M22WL
# 305 https://www.reuters.com/article/employment-uber/uber-moves-for-scotus-review-of-philly-drivers-misclassification-claims-idUSL1N2M22DC
# 306 https://www.reuters.com/article/dataprivacy-wiretaprulings/rulings-derail-website-tracking-cases-finding-wiretap-claims-dont-stick-idUSL1N2M22TT
# 307 https://www.reuters.com/news/archive/westLaw?view=page&page=1&pageSize=10
# 308 https://www.reuters.com/article/idUSKBN2BM329
# 309 https://www.reuters.com/article/us-otc-ada/11th-circuits-winn-dixie-ruling-deepens-confusion-on-ada-and-digital-access-idUSKBN2BV2UU
# 310 https://www.reuters.com/article/us-otc-tuna/9th-circuit-decertifies-tuna-price-fixing-classes-clamps-down-on-uninjured-class-members-idUSKBN2BU37T
# 311 https://www.reuters.com/article/us-otc-j-j/defendants-new-supreme-court-dream-case-jjs-challenge-to-2-billion-talc-judgment-idUSKBN2BU2CQ
# 312 https://www.reuters.com/article/us-usa-court-facebook/u-s-supreme-court-backs-facebook-in-case-about-unwanted-texting-idUSKBN2BO5UA
# 313 https://www.reuters.com/article/idUSKBN2BO5S4
# 314 https://www.reuters.com/article/us-usa-court-ncaa/ncaa-plays-defense-in-u-s-supreme-court-athlete-compensation-case-idUSKBN2BN1BI
# 315 https://www.reuters.com/article/us-usa-court-transunion/u-s-supreme-court-weighs-transunion-bid-to-nix-terrorist-list-lawsuit-idUSKBN2BM2OS
# 316 https://www.reuters.com/subjects/supreme-court
# 317 https://www.reuters.com/article/us-global-oil/oil-prices-climb-on-favourable-outlook-for-u-s-fuel-demand-idUSKBN2BZ06I
# 318 https://www.reuters.com/article/us-health-coronavirus-canada-oilsands/covid-19-surge-complicates-busy-maintenance-season-for-canadas-oil-sands-idUSKBN2BW1AZ
# 319 https://www.reuters.com/article/us-usa-crude-cash/mars-sour-crude-weakens-despite-widening-brent-wti-spread-idUSKBN2BW2UM
# 320 https://www.reuters.com/article/us-saudi-aramco-pipeline-stakesale/aramco-signs-12-4-billion-pipeline-deal-with-eig-led-consortium-idUSKBN2BW2RM
# 321 https://www.reuters.com/article/us-petrobras-sepia/brazils-petrobras-government-agree-on-rules-for-potential-sepia-atapu-sale-idUSKBN2BX00L
# 322 https://www.reuters.com/article/us-refinery-operations-marathon-galvesto/marathon-galveston-bay-refinery-in-texas-restarts-gasoline-unit-reformer-sources-idUSKBN2BW29Y
# 323 https://www.reuters.com/article/us-usa-oil-fed-survey/great-plains-rockies-oil-and-gas-drilling-ticks-higher-fed-report-idUSKBN2BW2GE
# 324 https://www.reuters.com/article/us-usa-rigs-baker-hughes/u-s-drillers-add-gas-rigs-hold-oil-rigs-steady-this-week-baker-hughes-idUSKBN2BW2EL
# 325 https://www.reuters.com/news/archive/rcomus_energy?view=page&page=2&pageSize=10
# 326 https://www.reuters.com/video/2021/04/09/fight-the-fed-on-inflation-advisor?videoId=728288689&videoChannel=5
# 327 https://www.reuters.com/video/2021/04/09/jj-shot-shipments-to-be-low-until-fda-ok?videoId=728286306&videoChannel=5
# 328 https://www.reuters.com/article/us-indonesia-quake/indonesian-president-orders-java-rescue-efforts-after-quake-kills-8-idUSKBN2BY0B7
# 329 https://www.reuters.com/article/us-environment-oceans/illegal-driftnet-use-widespread-in-indian-ocean-greenpeace-says-idUSKBN2BY065
# 330 https://www.reuters.com/article/us-climate-change-france-flights/french-lawmakers-approve-a-ban-on-short-domestic-flights-idUSKBN2BY0AO
# 331 https://www.reuters.com/article/us-australia-cyclone/evacuation-centres-open-as-cyclone-intensifies-off-western-australia-idUSKBN2BY033
# 332 https://www.reuters.com/article/us-serbia-ecology-protests/thousands-protest-in-belgrade-demand-government-action-to-stop-pollution-idUSKBN2BX0C9
# 333 https://www.reuters.com/article/us-california-whales/four-dead-whales-wash-ashore-on-san-francisco-bay-area-beaches-idUSKBN2BX0KE
# 334 https://www.reuters.com/news/archive/environmentnews?view=page&page=2&pageSize=10
# 335 https://www.reuters.com/article/us-credit-suisse-gp-risks/swiss-watchdog-asked-credit-suisse-on-greensill-risks-sonntagszeitung-idUSKBN2BY09B
# 336 https://www.reuters.com/article/us-credit-suisse-asset-management-m-a-ex/exclusive-blackrock-mustiers-blank-check-firm-eye-credit-suisse-fund-management-arm-sources-idUSKBN2BW2CT
# 337 https://www.reuters.com/article/us-didi-ipo-banks-exclusive/exclusive-chinas-didi-picks-goldman-morgan-stanley-for-mega-u-s-ipo-sources-idUSKBN2BW0TG
# 338 https://www.reuters.com/article/us-health-coronavirus-hsbc-hldg/hsbc-and-asian-development-bank-join-forces-in-300-million-vaccine-financing-idUSKBN2BV38L
# 339 https://www.reuters.com/article/us-usa-markets-blocktrades-senate/u-s-senate-banking-chair-presses-wall-street-banks-on-archegos-ties-idUSKBN2BV2DG
# 340 https://www.reuters.com/article/us-usa-markets-blocktrades-nomura-hldgs/japans-nomura-to-investigate-archegos-related-loss-sources-idUSKBN2BV17L
# 341 https://www.reuters.com/article/us-usa-markets-blocktrades-credit-suisse/analysis-credit-suisse-in-search-of-new-map-after-losing-way-with-archegos-idUSKBN2BU1OJ
# 342 https://www.reuters.com/news/archive/bank-news?view=page&page=2&pageSize=10
# 343 https://www.reuters.com/article/us-usa-police-virginia/u-s-army-lieutenant-files-suit-against-two-virginia-police-for-assault-during-traffic-stop-idUSKBN2BX0II
# 344 https://www.reuters.com/article/us-usa-boxoffice/box-office-godzilla-vs-kong-roars-to-13-4-million-in-second-weekend-idUSKBN2BY0JY
# 345 https://www.reuters.com/article/us-awards-bafta/jazz-drama-ma-rainey-wins-two-prizes-at-baftas-opening-night-idUSKBN2BX06I
# 346 https://www.reuters.com/article/us-film-top-gun/top-gun-sequel-delayed-in-summer-movie-setback-for-theaters-idUSKBN2BW2KP
# 347 https://www.reuters.com/article/us-china-internet-mukbang/chinas-graft-watchdog-rebukes-mukbang-binge-eating-drinking-videos-idUSKBN2BX09I
# 348 https://www.reuters.com/article/us-music-taylor-swift/taylor-swift-releases-re-recording-of-hit-2008-fearless-album-idUSKBN2BW1GX
# 349 https://www.reuters.com/article/us-britain-royals-philip-flowers/britain-mourns-prince-philip-but-no-flowers-please-due-to-covid-idUSKBN2BW2ED
# 350 https://www.reuters.com/article/us-people-dmx/rapper-actor-dmx-five-time-billboard-chart-topper-dead-at-50-idUSKBN2BW2AG
# 351 https://www.reuters.com/news/archive/rcom-media-telecoms?view=page&page=2&pageSize=10
# 352 https://www.reuters.com/article/us-health-coronavirus-roche-regeneron-ph/regenerons-covid-19-cocktail-helps-prevent-symptomatic-disease-study-idUSKBN2BZ0CG
# 353 https://www.reuters.com/news/archive/healthnews?view=page&page=2&pageSize=10
# 354 https://www.reuters.com/video/2018/07/09/arkansans-fear-losing-medicaid-with-new?videoId=443898507&videoChannel=118164
# 355 https://www.reuters.com/article/us-autos-semiconductors-white-house/white-house-convening-summit-with-top-execs-on-chip-shortage-idUSKBN2BW2AY
# 356 https://www.reuters.com/article/us-boeing-jobs/boeing-union-to-vote-on-whether-to-authorize-strike-idUSKBN2BW2OX
# 357 https://www.reuters.com/article/us-gm-semiconductors/gm-cuts-some-u-s-truck-production-shifts-because-of-chip-shortage-idUSKBN2BW2R0
# 358 https://www.reuters.com/article/us-boeing-737max-electrical-problem/boeing-production-issue-prompts-airlines-to-pull-some-737-max-jets-from-service-idUSKBN2BW1EE
# 359 https://www.reuters.com/article/us-airbus-deliveries/airbus-deliveries-surge-in-march-sending-shares-higher-idUSKBN2BV2HL
# 360 https://www.reuters.com/article/us-health-coronavirus-uber-lyft-focus/uber-lyft-use-rides-to-vaccines-to-get-drivers-customers-back-on-the-platform-idUSKBN2BW1KU
# 361 https://www.reuters.com/article/us-hong-kong-security-corporate/some-hong-kong-lawmakers-criticise-plans-to-mask-company-directors-data-idUSKBN2BW10J
# 362 https://www.reuters.com/article/us-volkswagen-regulator-australia/volkswagen-loses-a125-million-fine-appeal-for-emissions-breach-in-australia-regulator-idUSKBN2BW13Y
# 363 https://www.reuters.com/article/us-hyundai-motor-semiconductor/south-koreas-hyundai-motor-to-suspend-asan-plant-output-over-chip-shortage-idUSKBN2BW0LG
# 364 https://www.reuters.com/article/us-amazon-com-union/amazon-union-drive-losing-by-wide-margin-with-nearly-half-the-votes-counted-idUSKBN2BV1SO
# 365 https://www.reuters.com/news/archive/autos-upclose?view=page&page=2&pageSize=10
# 366 https://www.reuters.com/article/us-ford-motor-mach-e/some-early-ford-mustang-mach-e-owners-suffer-dead-batteries-idUSKBN2BV2YB
# 367 https://www.reuters.com/article/us-volvo-ssab/volvo-ssab-plan-first-fossil-free-steel-trucks-on-road-to-carbon-neutrality-idUSKBN2BV14G
# 368 https://www.reuters.com/article/us-usa-tax-biden/biden-willing-to-negotiate-on-corporate-taxes-but-sick-and-tired-of-non-payers-idUSKBN2BU2I2
# 369 https://www.reuters.com/article/us-usa-biden-taxes-alt/u-s-senate-readying-legislation-on-semiconductors-biden-says-idUSKBN2BU32I
# 370 https://www.reuters.com/article/us-nikola-schneider/nikolas-fuel-cell-development-head-exits-shares-fall-idUSKBN2BU2W9
# 371 https://www.reuters.com/article/us-usa-europe-tariffs/eu-proposes-six-month-tariff-freeze-with-united-states-der-spiegel-idUSKBN2BX070
# 372 https://www.reuters.com/article/us-boeing-737max-turkey/turkish-airlines-to-fly-737-max-jets-after-authority-approval-source-idUSKBN2BW1RB
# 373 https://www.reuters.com/article/us-global-markets-themes/take-five-whos-afraid-of-u-s-inflation-idUSKBN2BW1MS
# 374 https://www.reuters.com/article/us-business-aviation-m-a/rebounding-private-flights-fuel-ma-interest-in-corporate-jet-services-providers-idUSKBN2BW1A2
# 375 https://www.reuters.com/news/archive/aerospace-defense?view=page&page=2&pageSize=10
# 376 https://www.reuters.com/video/2018/07/18/why-your-plane-might-be-hackers-next-tar?videoId=446527693&videoChannel=118264
# 377 https://www.reuters.com/video/2018/07/17/rising-oil-price-spurs-jet-buying-bonanz?videoId=446212418&videoChannel=118264
# 378 https://www.reuters.com/video/2018/07/16/qatar-airways-ceo-shrugs-off-blockade-co?videoId=445921270&videoChannel=118264
# 379 https://www.reuters.com/article/us-change-suite-recalculate/missed-your-turn-recalculate-your-career-route-idUSKBN2BM09V
# 380 https://www.reuters.com/article/us-change-suite-connecting/network-outage-how-to-reconnect-in-an-era-of-isolation-idUSKBN2BG0DD
# 381 https://www.reuters.com/article/us-britain-economy-trade/the-covid-brexit-cocktail-uk-lost-market-share-in-u-s-germany-and-china-report-idUSKBN2B0001
# 382 https://www.reuters.com/article/us-health-coronavirus-travel-insurance/covid-19-travel-insurance-becoming-a-vacation-staple-idUSKBN2AZ0DV
# 383 https://www.reuters.com/article/us-autos-volvo-electric/betting-on-death-of-petrol-cars-volvo-to-go-all-electric-by-2030-idUSKBN2AU0AU
# 384 https://www.reuters.com/article/us-ceraweek-oil-investment/oil-executives-expect-crude-demand-to-climb-even-as-renewables-are-in-vogue-idUSKBN2AT33R
# 385 https://www.reuters.com/article/us-ceraweek-colombia-isabritain-eu-audit/ecopetrols-purchase-of-isa-shares-could-provide-income-stability-regulator-idUSKBN2AT2XJ
# 386 https://www.reuters.com/article/us-ceraweek-bill-gates/bill-gates-urges-need-to-reduce-green-premium-in-energy-transition-idUSKBN2AT2Q4
# 387 https://www.reuters.com/video/2021/02/22/why-recycling-rates-vary-around-the-worl?videoId=726310573&videoChannel=118318
# 388 https://www.reuters.com/video/2021/02/22/making-the-most-of-online-learning-beyon?videoId=726310574&videoChannel=118318
# 389 https://www.reuters.com/video/2021/02/15/father-of-the-web-prepares-a-do-over?videoId=725958136&videoChannel=118318
# 390 https://www.reuters.com/article/us-japan-economy-foodwaste/japanese-companies-go-high-tech-in-the-battle-against-food-waste-idUSKCN2AS0RI
# 391 https://www.reuters.com/article/us-britain-fintech/britain-to-offer-fast-track-visas-to-bolster-fintechs-after-brexit-idUSKBN2AQ0OV
# 392 https://www.reuters.com/article/us-change-suite-globalpayments/quick-response-how-to-touch-customers-in-contactless-commerce-idUSKBN2AQ0ER
# 393 https://www.reuters.com/article/us-huawei-electric-exclusive/exclusive-chinas-huawei-reeling-from-u-s-sanctions-plans-foray-into-evs-sources-idUSKBN2AQ0KD
# 394 https://www.reuters.com/article/us-britain-fintech-factbox/factbox-keeping-fintech-in-britain-fit-after-brexit-idUSKBN2AQ0QC
# 395 https://www.reuters.com/article/us-climate-change-offsets-insight/carbon-offsets-gird-for-lift-off-as-big-money-gets-close-to-nature-idUSKBN2AP1F2
# 396 https://www.reuters.com/article/us-eu-summit-merkel/digital-vaccination-passports-likely-available-before-summer-merkel-says-idUSKBN2AP2OX
# 397 https://www.reuters.com/article/us-health-coronavirus-europe-passports-f/a-patchwork-europe-and-covid-19-vaccination-passports-idUSKBN2AP2GW
# ...
# 828 https://www.reuters.com/article/us-cricket-india-stadium-modi/india-renames-worlds-largest-cricket-stadium-after-pm-modi-idUSKBN2AO1GT
# 829 https://www.reuters.com/article/us-cricket-usa-league/ipls-knight-riders-buy-stake-in-u-s-based-major-league-cricket-idUSKBN28B5FM
# 830 https://www.reuters.com/news/archive/sport-sailing
# 831 https://www.reuters.com/article/us-sailing-americas-cup/one-off-americas-cup-match-a-backwards-step-says-new-york-yacht-club-commodore-idUSKBN2BD05S
# 832 https://www.reuters.com/article/us-sailing-americas-cup/sailing-nz-accepts-british-americas-cup-challenge-nationality-rule-added-idUSKBN2BB08Q
# 833 https://www.reuters.com/article/us-sailing-americas-cup/sailing-team-new-zealand-savour-americas-cup-triumph-in-home-waters-idUSKBN2B90GK
# 834 https://www.reuters.com/article/us-rugby-union-nations-women/rugby-england-crush-scotland-52-10-in-womens-six-nations-opener-idUSKBN2BQ0II
# 835 https://www.reuters.com/article/us-rugby-union-super-au/rugby-reds-make-it-six-wins-out-six-to-top-super-rugby-au-standings-idUSKBN2BQ0AM
# 836 https://www.reuters.com/article/us-rugby-lgbt-sport-trfn/england-rugby-proposes-height-weight-limits-for-trans-women-idUSKBN2BN2Q4
# 837 https://www.reuters.com/news/archive/sport-athletics
# 838 https://www.reuters.com/article/olympics-2020-athletics-australia/olympics-australia-pulls-out-of-athletics-relay-championships-due-to-covid-19-idUSL4N2M50S5
# 839 https://www.reuters.com/article/athletics-doping-russia/athletics-russian-former-indoor-1500-metres-champion-soboleva-gets-eight-year-doping-ban-idUSL1N2M01ER
# 840 https://www.reuters.com/article/us-athletics-shoes/athletics-briton-hutchings-calls-for-records-reset-for-high-tech-shoes-era-idUSKBN2BU0CU
# 841 https://www.reuters.com/article/us-health-coronavirus-science/moderna-vaccine-antibodies-last-at-least-6-months-lung-transplant-can-save-some-covid-19-survivors-idUSKBN2BW24Q
# 842 https://www.reuters.com/article/us-chile-science-new-mammal/beast-of-five-teeth-chilean-scientists-unearth-skunk-that-walked-among-dinosaurs-idUSKBN2BV36M
# 843 https://www.reuters.com/article/us-science-dna/bulgarian-cave-remains-reveal-surprises-about-earliest-homo-sapiens-in-europe-idUSKBN2BU3FQ
# 844 https://www.reuters.com/article/us-climate-change-seagrass/shrinking-sea-meadows-store-more-carbon-than-forests-scientists-are-racing-to-track-whats-left-idUSKBN2BV0MV
# 845 https://www.reuters.com/article/us-space-exploration-china/china-begins-construction-of-its-fifth-rocket-launch-site-idUSKBN2BV0CF
# 846 https://www.reuters.com/article/us-climate-change-oceans-life/climate-change-shrinks-marine-life-richness-near-equator-study-idUSKBN2BS1Y4
# 847 https://www.reuters.com/article/us-health-coronavirus-science/vaccinating-adults-appears-to-protect-children-around-them-bar-opening-event-linked-to-46-covid-19-cases-idUSKBN2BS1SS
# 848 https://www.reuters.com/article/us-health-coronavirus-who-china/scientists-call-for-new-probe-into-covid-19-origins-with-or-without-china-idUSKBN2BU2J2
# 849 https://www.reuters.com/article/us-health-coronavirus-venezuela/venezuela-doctors-and-scientists-urge-covid-19-vaccination-progress-as-cases-spike-idUSKBN2BS1EU
# 850 https://www.reuters.com/news/archive/sciencenews?view=page&page=2&pageSize=10
# 851 https://www.reuters.com/finance/investing
# 852 https://www.reuters.com/news/archive/wealth-taxes
# 853 https://www.reuters.com/article/us-usa-treasury-budget/biden-budget-would-beef-up-irs-tax-enforcement-yellen-idUSKBN2BW25C
# 854 https://www.reuters.com/article/us-imf-worldbank/imf-world-bank-urged-to-aid-middle-income-country-debt-distress-climate-transitions-idUSKBN2BW1ZO
# 855 https://www.reuters.com/article/us-usa-biden-infrastructure/biden-to-meet-with-u-s-lawmakers-monday-on-infrastructure-plan-idUSKBN2BW248
# 856 https://www.reuters.com/news/archive/wealth-family
# 857 https://www.reuters.com/article/us-intesa-sanpaolo-ceo-wealth-management/intesa-ceo-says-wealth-management-sector-too-pricey-for-large-deals-idUSKBN2A80Y8
# 858 https://www.reuters.com/article/us-change-suite-scrivner/starting-a-job-dream-big-and-dont-be-afraid-to-fail-says-wella-ceo-idUSKBN29B0FQ
# 859 https://www.reuters.com/news/archive/wealth-retirement
# 860 https://www.reuters.com/article/us-amazon-com-sec-vote/u-s-sec-blocks-amazon-effort-to-stop-shareholder-votes-on-racial-equity-audit-idUSKBN2BU38U
# 861 https://www.reuters.com/article/us-usa-biden-infrastructure-care/top-white-house-economist-defends-care-economy-as-infrastructure-idUSKBN2BU02A
# 862 https://www.reuters.com/article/us-jcpenny-pension-athene-hldg-exclusive/exclusive-athene-to-take-over-2-8-billion-in-j-c-penney-pension-obligations-idUSKBN2BO6GW
# 863 https://www.reuters.com/video/2021/04/09/fight-the-fed-on-inflation-advisor?videoId=728288689&videoChannel=303
# 864 https://www.reuters.com/video/2021/04/08/buy-energy-small-caps-on-dip-hogan?videoId=728247926&videoChannel=303
# 865 https://www.reuters.com/video/2021/04/07/big-tech-is-part-of-the-reopening-trade?videoId=728207025&videoChannel=303
# 866 https://www.reuters.com/article/us-hedgefunds-melvin/hedge-fund-melvin-capital-lost-49-on-its-investments-in-q1-source-idUSKBN2BW2Q2
# 867 https://www.reuters.com/article/us-markets-flows/melt-up-more-money-poured-into-stocks-in-past-5-months-than-last-12-years-idUSKBN2BW15S
# 868 https://www.reuters.com/article/us-blucora-board-glasslewis/proxy-adviser-iss-backs-one-of-ancoras-board-nominees-at-blucora-idUSKBN2BW2F7
# 869 https://www.reuters.com/article/us-gamestop-board-hestia-exclusive/exclusive-gamestops-strong-stock-performance-triggered-board-directors-exit-idUSKBN2BV2VW
# 870 https://www.reuters.com/article/us-investment-diversifcation-analysis/analysis-investments-get-real-as-inflation-fears-dim-appeal-of-bonds-idUSKBN2BV1MR
# 871 https://www.reuters.com/article/us-usa-wealthy-taxes/millionaires-tax-threat-has-some-ny-bankers-managers-eyeing-exits-idUSKBN2BT2WX
# 872 https://www.reuters.com/article/us-morgan-stanley-archegos/morgan-stanley-dumped-5-billion-in-archegos-stock-night-before-fire-sale-cnbc-idUSKBN2BT2OC
# 873 https://www.reuters.com/article/us-usa-funds-quarter/value-small-cap-funds-outperform-in-first-quarter-as-u-s-inflation-worries-rise-idUSKBN2BO6NA
# 874 https://www.reuters.com/news/archive/personalfinance?view=page&page=2&pageSize=10
# 875 https://www.reuters.com/subjects/life-lessons
# 876 https://www.reuters.com/article/us-money-lifelessons-bellamyyoung/presidential-material-life-lessons-with-bellamy-young-idUSKBN1YL253
# 877 https://www.reuters.com/article/us-money-lifelessons-harrisrosen/local-hero-florida-hotelier-harris-rosen-keeps-his-giving-close-to-home-idUSKBN1Y01VY
# 878 https://www.reuters.com/article/us-money-lifelessons-brookeshields/a-model-life-life-lessons-with-brooke-shields-idUSKBN1W91C0
# 879 https://www.reuters.com/article/us-california-theme-park-sugar-rush/eye-candy-getting-high-at-californias-sugar-rush-theme-park-idUSKBN2BU3G0
# 880 https://www.reuters.com/article/us-cyprus-halloumi/say-cheese-cypruss-halloumi-gets-eu-protected-status-idUSKBN2BT27P
# 881 https://www.reuters.com/article/us-southkorea-graffiti-vandalism/cctv-shows-couple-in-seoul-daubing-over-500000-graffiti-artwork-idUSKBN2BP0SV
# 882 https://www.reuters.com/article/us-sri-lanka-pageant/crowned-de-crowned-crowned-again-chaos-at-sri-lankan-beauty-pageant-idUSKBN2BU1F0
# 883 https://www.reuters.com/article/us-health-coronavirus-sweden-meme/internets-hide-the-pain-harold-accidentally-used-by-swedish-covid-19-vaccine-website-idUSKBN2BN1RM
# 884 https://www.reuters.com/article/us-australia-octopus/angriest-octopus-lashes-out-at-man-on-australia-beach-idUSKBN2BO4UW
# 885 https://www.reuters.com/article/us-asahi-group-australia-solar/power-drinkers-aussie-brewer-offers-beer-for-excess-solar-energy-idUSKBN2BN16N
# 886 https://www.reuters.com/article/us-health-coronavirus-belgium-party/police-disperse-thousands-at-belgian-april-fool-party-idUSKBN2BO56G
# 887 https://www.reuters.com/article/us-china-trump-statue/be-at-peace-meditate-trump-buddha-statue-designer-tells-former-president-idUSKBN2BN0RU
# 888 https://www.reuters.com/news/archive/oddlyenoughnews?view=page&page=2&pageSize=10
# 889 https://www.reuters.com/article/pictures-report/photos-of-the-week-idUSRTXBCF81
# 890 https://www.reuters.com/news/picture/hideki-matsuyama-wins-the-masters-idUSRTXBE53X
# 891 https://www.reuters.com/news/picture/fans-mourn-rapper-dmx-in-new-york-idUSRTXBE42L
# 892 https://www.reuters.com/news/picture/britain-mourns-passing-of-prince-philip-idUSRTXBC2RP
# 893 https://www.reuters.com/news/picture/migrants-deported-from-us-find-shelter-i-idUSRTXBC0J2
# 894 https://www.reuters.com/news/picture/notable-deaths-in-2021-idUSRTR4Z4Y0
# 895 https://www.reuters.com/news/picture/prince-philip-1921-2021-idUSRTXBBW5S
# 896 https://www.reuters.com/news/picture/migrants-cross-rio-grande-under-cover-of-idUSRTXBC4NF
# 897 https://www.reuters.com/news/picture/worst-violence-in-years-rocks-northern-i-idUSRTXBC0ZW
# 898 https://www.reuters.com/news/pictures/archive?page=2&pageSize=9
# 899 https://www.reuters.com/video/2021/03/31/images-of-march?videoId=727951398&videoChannel=118069
# 900 https://www.reuters.com/video/2021/03/01/images-of-february?videoId=726653738&videoChannel=118069
# 901 https://www.reuters.com/video/2021/02/01/images-of-january?videoId=725142268&videoChannel=118069
# 902 https://www.reuters.com/video/breakingviews
# 903 https://www.reuters.com/video/business
# 904 https://www.reuters.com/video/marketsnow
# 905 https://www.reuters.com/video/great-reboot
# 906 https://www.reuters.com/video/change-suite
# 907 https://www.reuters.com/video/sectors-upclose
# 908 https://www.reuters.com/video?feat=1WgdzxmbJQ4M
# 909 https://www.reuters.com/video/technology
# 910 https://www.reuters.com/video/world
# 911 https://www.reuters.com/video/entertainment
# 912 https://www.reuters.com/video/politics
# 913 https://www.reuters.com/video/oddly-enough
# 914 https://www.reuters.com/news/archive/healthPharmaNews
# 915 https://www.reuters.com/news/archive/coronavirus-cure
# 916 https://www.reuters.com/journalists/aislinn-laing
# 917 https://www.reuters.com/news/archive/domesticNews
# 918 https://www.reuters.com/journalists/nicholas-pfosi
# 919 https://www.reuters.com/journalists/jonathan-allen
# 920 https://www.reuters.com/news/archive/retail
# 921 https://www.reuters.com/journalists/josh-horwitz
# 922 https://www.reuters.com/journalists/yilei-sun
# 923 https://www.reuters.com/news/archive/rcom-media-telecoms
# 924 https://www.reuters.com/journalists/jessica-dinapoli
# 925 https://www.reuters.com/news/archive/rcom-emerging-markets
# 926 https://www.reuters.com/journalists/marco-aquino
# 927 https://www.reuters.com/news/archive/us-the-wire?view=page&page=2&pageSize=10
# 928 https://www.reuters.com/news/archive/businessNews
# 929 https://www.reuters.com/journalists/wayne-cole
# 930 https://www.reuters.com/news/archive/autos-upclose
# 931 https://www.reuters.com/journalists/heekyong-yang
# 932 https://www.reuters.com/journalists/joyce-lee
# 933 https://www.reuters.com/journalists/nick-carey
# 934 https://www.reuters.com/journalists/kate-abnett
# 935 https://www.reuters.com/news/archive/rcom-us-markets
# 936 https://www.reuters.com/journalists/kate-duguid
# 937 https://www.reuters.com/journalists/rocky-swift
# 938 https://www.reuters.com/news/archive/technologyNews
# 939 https://www.reuters.com/journalists/lee-ying-shan
# 940 https://www.reuters.com/journalists/alexandra-valencia
# 941 https://www.reuters.com/journalists/brian-ellsworth
# 942 https://www.reuters.com/news/archive/bank-news
# 943 https://www.reuters.com/news/archive/mediaNews
# 944 https://www.reuters.com/journalists/prak-chan-thul
# 945 https://www.reuters.com/journalists/kay-johnson
# 946 https://www.reuters.com/news/archive/reboot-live
# 947 https://www.reuters.com/news/archive/rcom-apac
# 948 https://www.reuters.com/news/archive/ousivMolt
# 949 https://www.reuters.com/journalists/leika-kihara
# 950 https://www.reuters.com/news/archive/rcom-eur-markets
# 951 https://www.reuters.com/journalists/kevin-buckland
# 952 https://www.reuters.com/journalists/paulina-duran
# 953 https://www.reuters.com/journalists/andrew-both
# 954 https://www.reuters.com/article/us-health-coronavirus-france-actors/french-audiences-develop-a-taste-for-window-theatre-idUSKBN2BY0M8
# 955 https://www.reuters.com/article/us-netflix-sony/spider-man-and-other-sony-films-to-hit-netflix-after-theaters-idUSKBN2BV2NZ
# 956 https://www.reuters.com/article/us-nike-lil-nas-x/nike-ends-lawsuit-over-lil-nas-x-satan-shoes-which-will-be-recalled-idUSKBN2BV304
# 957 https://www.reuters.com/news/archive/entertainmentnews?view=page&page=2&pageSize=10
# 958 https://www.reuters.com/journalists/marie-louise-gumuchian
# 959 https://www.reuters.com/journalists/dan-burns
# 960 https://www.reuters.com/journalists/howard-schneider
# 961 https://www.reuters.com/journalists/hyonhee-shin
# 962 https://www.reuters.com/journalists/parisa-hafezi
# 963 https://www.reuters.com/news/archive/lifestyleMolt
# 964 https://www.reuters.com/journalists/syed-raza-hassan
# 965 https://www.reuters.com/news/picture/madrid-fashion-week-kicks-off-after-toug-idUSRTXBC044
# 966 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTXBBWHD
# 967 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTXBB6ML
# 968 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTXB9SZL
# 969 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTXB8CH6
# 970 https://www.reuters.com/news/archive/esgNews
# 971 https://www.reuters.com/journalists/samuel-shen
# 972 https://www.reuters.com/journalists/scott-murdoch
# 973 https://www.reuters.com/journalists/paresh-dave
# 974 https://www.reuters.com/journalists/steve-holland
# 975 https://www.reuters.com/news/archive/environmentNews
# 976 https://www.reuters.com/journalists/trevor-hunnicutt
# 977 https://www.reuters.com/article/us-usa-biden-budget-takeaways2/seven-takeaways-from-bidens-budget-proposal-defense-immigration-climate-idUSKBN2BW2DQ
# 978 https://www.reuters.com/article/us-usa-pentagon-auditor/pentagon-fails-audit-yet-again-could-pass-around-2027-comptroller-says-idUSKBN27X03P
# 979 https://www.reuters.com/news/archive/BigStory11
# 980 https://www.reuters.com/journalists/tom-daly
# 981 https://www.reuters.com/news/archive/innovationNewsIndustryMaterialsAndUtilities
# 982 https://www.reuters.com/journalists/joshua-franklin
# 983 https://www.reuters.com/news/archive/innovationNewsHealthcare
# 984 https://www.reuters.com/article/factcheck-biden-ratings/corrected-fact-check-gallup-says-bidens-approval-rating-is-54-not-11-idUSL1N2M2329
# 985 https://www.reuters.com/article/factcheck-biden-ratings/corrected-fact-check-gallup-says-bidens-approval-rating-is-54-not-11-idUSL1N2M2275
# 986 https://www.reuters.com/article/factcheck-shipping-container/fact-check-video-shows-a-refuge-chamber-used-in-hazardous-environments-not-a-shipping-container-used-to-transport-humans-idUSL1N2M22BP
# 987 https://www.reuters.com/article/factcheck-jellyfish/fact-check-picture-does-not-show-spanish-dancer-jellyfish-from-papua-new-guinea-idUSL1N2M223K
# 988 https://www.reuters.com/article/factcheck-russia-parade/fact-check-photo-shows-man-walking-at-a-parade-in-russia-in-2007-idUSL1N2M21ZH
# 989 https://www.reuters.com/article/factcheck-slavery-photo/fact-check-photos-of-anti-slavery-activist-lewis-hayden-falsely-labeled-as-first-slave-owner-idUSL1N2M21FG
# 990 https://www.reuters.com/article/factcheck-evergiven-qplusclintons/fact-check-q-did-not-predict-container-ship-jam-in-the-suez-canal-ship-not-linked-to-clintons-idUSL1N2M21EO
# 991 https://www.reuters.com/article/factcheck-evergiven-qplusclintons/fact-check-q-did-not-predict-container-ship-jam-in-the-suez-canal-ship-not-linked-to-clintons-idUSL1N2M21EC
# 992 https://www.reuters.com/article/factcheck-theonion-kidvideo/fact-check-the-onion-video-of-8-year-old-boy-talking-about-guns-taken-seriously-idUSL1N2M21EB
# 993 https://www.reuters.com/article/factcheck-hr1-missingcontext/fact-check-delving-into-social-media-claims-about-h-r-1-idUSL1N2M139F
# 994 https://www.reuters.com/news/archive/factchecknew?view=page&page=2&pageSize=10

# %% [markdown]
# ### 1.2.5. [5] Index statistics
#
# Load an index and print the statistics.

# %%
# load index, doc_lengths and doc_urls
with open('inverted_index.p', 'rb') as fp:
    index = pickle.load(fp)
with open('doc_lengths.p', 'rb') as fp:
    doc_lengths = pickle.load(fp)
with open('doc_urls.p', 'rb') as fp:
    doc_urls = pickle.load(fp)
    
    
print('Total index length', len(index))
print('\nTop terms by number of documents they apperared in:')
sorted_by_n_docs = sorted(index.items(), key=lambda kv: (len(kv[1]), kv[0]), reverse=True)
print([(sorted_by_n_docs[i][0], len(sorted_by_n_docs[i][1])) for i in range(20)])
print('\nTop terms by overall frequency:')
sorted_by_freq = sorted(index.items(), key=lambda kv: (kv[1][0], kv[0]), reverse=True)
print([(sorted_by_freq[i][0], sorted_by_freq[i][1][0]) for i in range(20)])
# Out:
# Total index length 9980
#
# Top terms by number of documents they apperared in:
# [('reuter', 490), ('s', 480), ('said', 434), ('ha', 377), ('wa', 366), ('have', 362), ('after', 310), ('thi', 303), ('more', 299), ('which', 298), ('year', 297), ('not', 297), ('but', 285), ('last', 260), ('had', 258), ('up', 254), ('also', 254), ('their', 245), ('than', 243), ('new', 243)]
#
# Top terms by overall frequency:
# [('s', 2465), ('said', 1594), ('wa', 1081), ('ha', 944), ('have', 905), ('reuter', 674), ('not', 674), ('more', 639), ('year', 636), ('but', 571), ('thi', 570), ('which', 566), ('after', 562), ('had', 529), ('new', 503), ('we', 500), ('who', 497), ('compani', 491), ('their', 484), ('i', 478)]

# %% [markdown]
# ## 1.3. [15] Answering a query (finally)
#
# Now, given that we already have built the inverted index, it's time to utilize it for answering user queries. In this class there are two methods you need to implement:
# - `boolean_retrieval`, the simplest form of document retrieval which returns a set of documents such that each one contains all query terms. Returns a set of document ids. Refer to *ch.1* of the book for details;
# - `okapi_scoring`, Okapi BM25 ranking function - assigns scores to documents in the collection that are relevant to the user query. Returns a dictionary of scores, `doc_id:score`. Read about it in [Wikipedia](https://en.wikipedia.org/wiki/Okapi_BM25#The_ranking_function) and implement accordingly.
#
# Both methods accept `query` parameter in a form of a dictionary, `term:frequency`

# %%
from collections import Counter
import math

class QueryProcessing:
    
    @staticmethod
    def prepare_query(raw_query):
        prep = Preprocessor()
        # pre-process query the same way as documents
        query = prep.preprocess(raw_query)
        # count frequency
        return Counter(query)
    
    @staticmethod
    def boolean_retrieval(query, index):
        #TODO retrieve a set of documents containing all query terms
        query_items = list(map(lambda x: x[0], query.items()))
    
        relev_docs = set(list(map(lambda x: x[0], index[query_items[0]][1:])))
        for term in query_items:
            relev_docs = relev_docs & set(list(map(lambda x: x[0], index[term][1:])))
        return relev_docs

    
    @staticmethod
    def okapi_scoring(query, doc_lengths, index, k1=1.2, b=0.75):

        N = len(doc_lengths)
        avg_length = sum(list(doc_lengths.values())) / N
        okapi = {}

        for doc_id, doc_length in doc_lengths.items():
            okapi_score = 0
            
            for term in query:
                n_q = len(index[term][1:])
                idf = math.log((N - n_q + 0.5) / (n_q + 0.5) + 1 )
                doc_ids = list(map(lambda x: x[0], index[term][1:]))
                if doc_id in doc_ids:
                    idx = doc_ids.index(doc_id)
                    term_freq = index[term][idx+1][1]
                else:
                    term_freq = 0
                koef = (term_freq * (k1 + 1)) / (term_freq + k1 * (1 - b + b * doc_length / avg_length))
                okapi_score += idf * koef

            if okapi_score != 0:
                okapi[doc_id] = okapi_score
            
        return okapi

# %% [markdown]
# ### 1.3.1. Tests

# %%
test_doc_lengths = {1: 20, 2: 15, 3: 10, 4:20, 5:30}
test_index = {'x': [2, (1, 1), (2, 1)], 'y': [2, (1, 1), (3, 1)], 'z': [3, (2, 1), (4,2)]}

test_query1 = QueryProcessing.prepare_query('x z')
test_query2 = QueryProcessing.prepare_query('x y')


assert QueryProcessing.boolean_retrieval(test_query1, test_index) == {2}
assert QueryProcessing.boolean_retrieval(test_query2, test_index) == {1}
okapi_res = QueryProcessing.okapi_scoring(test_query2, test_doc_lengths, test_index)
assert all(k in okapi_res for k in (1, 2, 3))
assert not any(k in okapi_res for k in (4, 5))
assert okapi_res[1] > okapi_res[3] > okapi_res[2]
okapi_res
# Out:
# {1: 1.7140324693860898, 2: 0.9579736445390843, 3: 1.0858929739285763}

# %% [markdown]
# # 2. [40] Sorri not veri gud in inglish
#
# Have you ever googled someone's name without knowing exactly how it should be written? Were you ever reluctant to look up the correct spelling of a query you typed? Or just unable to type properly because of being in a rush? Modern search engines usually do a pretty good job in deciphering defective user input. In order to be able to do that, a good spell-checking mechanism should be incorporated into a search procedure. Today we will take one step further towards building a good search engine and work on tolerant retrieval with respect to user queries. We will consider two cases:
#
# 1. Users know that they don't know the correct spelling OR they want to get the results that follow some known pattern, so the use so called wildcards - queries like `retr*val`;
# 2. Users don't know the correct spelling OR they don't care OR they are in a rush OR they expect that mistakes will be corrected OR /your option/... so they make mistakes and we need to handle them using:
#
#     2.1. Trigrams with Jaccard coefficient;
#
#     2.2. Simple spellchecker by Peter Norvig with QWERTY weights;

# %% [markdown]
# ## 2.1. [25] Handling wildcards
#
# We will handle wildcard queries using k-grams. K-gram is a list of consecutive k chars in a string - i.e., for the word *'star'*, it will be '*\$st*', '*sta*', '*tar*', and '*ar$*', if we take k=3. Take a look at [book](https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf) *chapter 3.2.2* to understand how k-grams can help efficiently match a wildcard against dictionary words. Here we will only consider wildcards with star symbols (may be multiple).
#
# Notice that for building k-grams index, **we will need a vocabulary of original word forms** to compare words in user input to the vocabulary of "correct" words (think why inverted index which we built for stemmed words doesn't work here).
#
# You need to implement the following:
#
# - `build_inverted_index_orig_forms` - creates inverted index of original world forms from `facts` list, which is already given to you.
#     Output format: `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#
#
# - `build_k_gram_index` - creates k-gram index which maps every k-gram encountered in facts collection to a list of words containing this k-gram. Use the abovementioned inverted index of original words to construct this index.
#     Output format: `'k_gram': ['word1_with_k_gram', 'word2_with_k_gram', ...]`
#
#
# - `generate_wildcard_options` - produce a list of vocabulary words matching given wildcard by intersecting postings of k-grams present in the wildcard (refer to *ch 3.2.2*).
#
# - `search_wildcard` - return list of facts that contain the words matching a wildcard query.
#
#
# We will use the dataset with curious facts for testing.
#
# ### 2.1.1. Downloading the dataset

# %%
import urllib.request
data_url = "https://raw.githubusercontent.com/IUCVLab/information-retrieval/main/datasets/facts.txt"
local_filename, headers = urllib.request.urlretrieve(data_url)

facts = []
with open(local_filename) as fp:
    for cnt, line in enumerate(fp):
        facts.append(line.strip('\n'))
        
print(*facts[-5:], sep='\n')
# Out:
# 151. Women have twice as many pain receptors on their body than men. But a much higher pain tolerance.
# 152. There are more stars in space than there are grains of sand on every beach in the world.
# 153. For every human on Earth there are 1.6 million ants.
# 154. The total weight of all those ants, however, is about the same as all the humans.
# 155. On Jupiter and Saturn it rains diamonds.

# %% [markdown]
# ### 2.1.2. [25] Implementation of search

# %%
import re


def build_inverted_index_orig_forms(documents):
    #TODO build an inverted index of original word forms 
    # (without stemming, just word tokenized and lowercased)
    inverted_index = {}
    prep = Preprocessor()
    
    for i, doc in enumerate(documents):
        words = prep.tokenize(doc.lower())
        words = list(filter(prep.is_apt_word, words))
        doc_id = i
        
        for word in words:
            if word in inverted_index:
                inverted_index[word][0] += 1
                doc_ids = list(map(lambda x: x[0], inverted_index[word][1:]))

                if doc_id in doc_ids:
                    ind = doc_ids.index(doc_id)
                    count = inverted_index[word][ind+1][1]
                    inverted_index[word][ind+1] = (doc_id, count+1)
                else:
                    inverted_index[word].append((doc_id, 1))
            else:
                inverted_index[word] = []
                inverted_index[word].append(1)
                inverted_index[word].append((doc_id, 1))
   
    return inverted_index


def build_k_gram_index(inverted_index, k):
    #TODO build index of k-grams for dictionary words. 
    # Padd with '$' ($word$) before splitting to k-grams    
    k_gram_index = {}
    
    for word in inverted_index:
        padded_word = "$" + word + "$"
        for i in range(len(padded_word) - k + 1):
            k_gram = padded_word[i:i+k]

            if k_gram not in k_gram_index:
                k_gram_index[k_gram] = []
                k_gram_index[k_gram].append(word)
            else:
                if word not in k_gram_index[k_gram]:
                    k_gram_index[k_gram].append(word)
    
    return k_gram_index


def generate_wildcard_options(wildcard, k_gram_index, inverted_index):
    #TODO for a given wildcard return all words matching it using k-grams
    # refer to book chapter 3.2.2
    # don't forget to pad wildcard with '$', when appropriate
    padded_wildcard = "$" + wildcard + "$"
    k = len(list(k_gram_index.items())[0][0])
    words = set(inverted_index.keys())
    
    for part in padded_wildcard.split("*"):
        for i in range(len(part) - k + 1):
            if part[i:i+k] in k_gram_index:
                words = words & set(k_gram_index[part[i:i+k]])
            else: 
                return []
    words = list(words)
    # a post-filtering step
    wildcard = wildcard.replace("*", ".+")
    
    return [w for w in words if re.search(wildcard, w)]


def search_wildcard(wildcard, k_gram_index, index, docs):
    #TODO retrive list of documnets (facts) that contain words matching wildcard
    words = generate_wildcard_options(wildcard, k_gram_index, index)
    resulted_docs = set()
    
    for w in words:
        for doc_id in list(map(lambda x: x[0], index[w][1:])):
            resulted_docs.add(docs[doc_id])
    return list(resulted_docs)

# %% [markdown]
# ### 2.1.3. Tests

# %%
index_orig_forms = build_inverted_index_orig_forms(facts)
k_gram_index = build_k_gram_index(index_orig_forms, 3)

wildcard = "re*ed"

wildcard_options = generate_wildcard_options(wildcard, k_gram_index, index_orig_forms)
print(wildcard_options)
assert(len(wildcard_options) >= 3)
assert("red" not in wildcard_options) 

wildcard_results = search_wildcard(wildcard, k_gram_index, index_orig_forms, facts)
# some pretty printing
for r in wildcard_results:
    # highlight terms for visual evaluation
    for term in wildcard_options:
        r = re.sub(r'(' + term + ')', r'\033[1m\033[91m\1\033[0m', r, flags=re.I)
    print(r)

assert(len(wildcard_results) >=3)

assert "13. James Buchanan, the 15th U.S. president continuously bought slaves with his own money in order to free them." in search_wildcard("pres*dent", k_gram_index, index_orig_forms, facts)
assert "40. 9 out of 10 Americans are deficient in Potassium." in search_wildcard("p*tas*um", k_gram_index, index_orig_forms, facts)
assert "61. A man from Britain changed his name to Tim Pppppppppprice to make it harder for telemarketers to pronounce." in search_wildcard("*price", k_gram_index, index_orig_forms, facts)
# Out:
# ['received', 'recorded', 'reduced']
# 134. A person can live without food for about a month, but only about a week without water. If the amount of water in your body is reduced by just 1%, you'll feel thirsty. If it's reduced by 10%, you'll die.
# 4. The largest recorded snowflake was in Keogh, MT during year 1887, and was 15 inches wide.
# 102. More than 50% of the people in the world have never made or received a telephone call.

# %% [markdown]
# ## 2.2. [15] Handling typos
#
# ### 2.2.0. Dataset
#
# Download github typo dataset from [here](https://github.com/mhagiwara/github-typo-corpus).
# Load it with this code:

# %%
# !pip install jsonlines
# Out:
# Requirement already satisfied: jsonlines in /opt/anaconda3/lib/python3.8/site-packages (2.0.0)
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import jsonlines

dataset_file = "github-typo-corpus.v1.0.0.jsonl"

dataset = []
other_langs = set()

with jsonlines.open(dataset_file) as reader:
    for obj in reader:
        for edit in obj['edits']:
            if edit['src']['lang'] != 'eng':
                other_langs.add(edit['src']['lang'])
                continue

            if edit['is_typo']:
                src, tgt = edit['src']['text'], edit['tgt']['text']
                if src.lower() != tgt.lower():
                    dataset.append((edit['src']['text'], edit['tgt']['text']))
                
print(f"Dataset size = {len(dataset)}")
# Out:
# Dataset size = 245909

# %% [markdown]
# #### Explore sample typos
# Please, explore the dataset. You may see, that this is
# - mostly markdown
# - some common mistakes with do/does
# - some just refer to punctuation typos (which we do not consider)

# %%
for pair in dataset[1010:1020]:
    print(f"{pair[0]} => {pair[1]}")
# Out:
#         """Make am instance. =>         """Make an instance.
# * travis: test agains Node.js 11 => * travis: test against Node.js 11
# The parser receive a string and returns an array inside a user-provided  => The parser receives a string and returns an array inside a user-provided
# CSV data is send through the `write` function and the resulted data is obtained => CSV data is sent through the `write` function and the resulting data is obtained
# One useful function part of the Stream API is `pipe` to interact between  => One useful function of the Stream API is `pipe` to interact between
# source to a `stream.Writable` object destination. This example available as  => source to a `stream.Writable` object destination. This example is available as
# `node samples/pipe.js` read the file, parse its content and transform it. => `node samples/pipe.js` and reads the file, parses its content and transforms it.
# Most of the generator is imported from its parent project [CSV][csv] in a effort  => Most of the generator is imported from its parent project [CSV][csv] in an effort
# *   `quote`             Optionnal character surrounding a field, one character only, defaults to double quotes.    => *   `quote`             Optional character surrounding a field, one character only, defaults to double quotes.
# The parser receive a string and return an array inside a user-provided  => The parser receive a string and returns an array inside a user-provided

# %% [markdown]
# #### 2.2.0.1. Build a dataset vocabulary
# Here we prepare a vocabulary for spellchecker testing and for estimating overall correction quality. Consider only word-level. Be carefull, there is markdown (e.g. \`name\`. \[url\]\(http://url)) and comment symbols (\#, //, \*).

# %%
def sent_to_words(sent):
    # splits sentence to words, filtering out non-alphabetical terms
    words = nltk.word_tokenize(sent)    
    words_filtered = filter(lambda x: x.isalpha(), words)
    return words_filtered

# %%
vocabulary = Counter()
for pair in dataset:
    for word in sent_to_words(pair[1].lower()):
        vocabulary[word] += 1
len(vocabulary)
# Out:
# 63724

# %%
from itertools import islice
print(list(islice(vocabulary.items(), 10)))
# Out:
# [('function', 6193), ('de', 82), ('deutsch', 4), ('nocomments', 2), ('you', 42075), ('can', 26027), ('disable', 532), ('comments', 360), ('for', 44756), ('the', 207017)]

# %% [markdown]
# ### 2.2.1. [15] Implement context-independent spellcheker (Trigrams with Jaccard coefficient) ##

# %%
def fix_typo_kgram(word, k_gram_index) -> list:
    # k = 3
    k = len(list(k_gram_index.keys())[0])
    k_grams = []
    
    padded_word = "$" + word + "$"
    for i in range(len(padded_word) - k + 1):
        k_grams.append(padded_word[i:i+k])
    
    words = []
    
    for k_gram in k_gram_index:
        if k_gram in k_grams:
            words.append(k_gram_index[k_gram])
            
    approp_words = set()

    for w in words:
        approp_words = approp_words | set(w)
    
    top_words = []
    
    for w in approp_words:
        w_k_grams = []
        padded_w = "$" + w + "$"
        
        for i in range(len(padded_w) - k + 1):
            w_k_grams.append(padded_w[i:i+k])

        jaccard_coef = len(set(w_k_grams) & set(k_grams)) / len(set(w_k_grams) | set(k_grams))
        
        if jaccard_coef > 0.3:
            top_words.append(w)
            
    return top_words

# %% [markdown]
# ### 2.2.2. Tests

# %%
# tests

k_gram_index_github = build_k_gram_index(vocabulary, 3)
print(fix_typo_kgram("enouh", k_gram_index_github)[:20])
assert "enough" in fix_typo_kgram("enouh", k_gram_index_github), "Assert k-gram failed"
# Out:
# ['enough', 'enought', 'eno']

# %% [markdown]
# ## 2.3. [Bonus]
#
# ### 2.3.1. QWERTY - Editorial distance
#
# Write code to compute weighted QWERTY-editorial distance.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/KB_United_States.svg/640px-KB_United_States.svg.png" width="640"/>
#
# Use this image to prepare weight function:
# - all letter pairs which share vertical border will get 0.5 multiplier **for replace** (`df`, `cv`, `ui`, ...)
# - all letter pairs which share at least some horizontal border will get 0.7 multiplier **for replace** (`dc`, `dr`, `km`, ...)
# - other operations are not scaled (x1 multiplier).

# %%
def replace_weight(let1, let2) -> float:
    # TODO what is the weight for a pair of letters being replaced? Note this function should be commutative
    horizontal  = [" ", "q", 'w', 'e', 'r', 't', 'y', 'u', 'y', 'u', 'i', 'o', 'p', ' ', 'a', 's', 'd', 'f', 'g', 'h', \
                   'j', 'k', 'l', ' ', 'z', 'x', 'c', 'v', 'b', 'n', 'm', " "]
    
    vertical = {"q": ["a"], "w": ["a", 's'], 'e': ['s', 'd'], 'r': ['d', 'f'], 
                't': ['f', 'g'], 'y': ['g', 'h'], 'u': ["h", 'j'], 'i': ["j", "k"], 'o': ['k', 'l'], 
                'p': ['l'], "a": ["q", "w", "z"], "s": ["e", "w", "z", "x"], "d": ["e", "r", "c", "x"], 
                "f": ["t", "r", "c", "v"], "g": ["t", "y", "b", "v"], "h": ["u", "y", "b", "n"], 
                "j": ["u", "i", "b", "m"], "k": ["o", "i", "m"], "l": ["o", "p"], "z": ["a", "s"], 
                "x": ["d", "s"], "c": ["d", "f"], "v": ["g", "f"], "b": ["g", "h"], "n": ["j", "h"], 
                "m": ["j", "k"]
               }
    if let1 in vertical[let2]:
        return 0.7
    elif horizontal[horizontal.index(let1)-1] == let2 or  horizontal[horizontal.index(let1)+1] == let2:
        return 0.5
    else:
        return 1

# read about Damerau-Levenshtein algorithm here 
# https://www.guyrutenberg.com/2008/12/15/damerau-levenshtein-distance-in-python/, so the code could be similar, as
# it was my reference
def qwerty_edit_dist(s1, s2):
    d = {}
    n = len(s1)
    m = len(s2)
    
    for i in range(-1, n + 1):
        d[(i, -1)] = i + 1
        
    for j in range(-1, m + 1):
        d[(-1, j)] = j + 1
 
    for i in range(n):
        
        for j in range(m):
            
            if s1[i] == s2[j]:
                replace_cost = 0
                
            else:
                replace_cost = replace_weight(s1[i], s2[j])
                
            d[(i,j)] = min(
                           d[(i-1,j)] + 1, 
                           d[(i,j-1)] + 1, 
                           d[(i-1,j-1)] + replace_cost, 
                          )
            if i > 0 and j > 0 and s1[i]==s2[j-1] and s1[i-1] == s2[j]:
                d[(i,j)] = min (d[(i,j)], d[i-2,j-2] + replace_cost) 
 
    return d[n-1, m-1]

# %%
# tests

assert qwerty_edit_dist("korrectud", "corrected") == 2.0, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("soem", "some") == 1.0, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("one", "one") == 0.0, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("fihure", "figure") == 0.5, "Edit distance is computed incorrectly"
assert qwerty_edit_dist("fivure", "figure") == 0.7, "Edit distance is computed incorrectly"

# %% [markdown]
# ### 2.3.2. Norvig's spellchecker with QWERTY weights
#
# You can base your code on [Norvig's corrector](https://norvig.com/spell-correct.html), but you should be sure you account the fact, that typos for close letters cost less. This should be considered in ranking.

# %%
def fix_typo_qwerty_norvig(word) -> str:
    #TODO return best matching result for the word
    
    return ""

# %%
# tests

assert fix_typo_qwerty_norvig("korrectud") == "corrected", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("speling") == "spelling", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("condidence") == "confidence", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("fpx") == "fox", "Norvig's correcter doesn't work"
assert fix_typo_qwerty_norvig("fux") == "fix", "Norvig's correcter doesn't work"

# %% [markdown]
# ### 2.3.3. Estimate quality of functions

# %%
norvig, kgram = 0, 0
limit = 10000
counter = limit
for i, (src, target) in enumerate(dataset):
    if i == limit:
        break
    words = sent_to_words(src.lower())
    # word suspected for typos
    sn, sk = src.lower(), src.lower()
    for word in words:
        if word not in vocabulary and word.isalpha():
            # top-1 accuracy
            wn, wk = fix_typo_qwerty_norvig(word), \
                     fix_typo_kgram(word, k_gram_index_github)[0]
            sn = sn.replace(word, wn)
            sk = sk.replace(word, wk)
    norvig += int(sn == target.lower())
    kgram += int(sk == target.lower())

print(f"Norvig accuracy ({norvig}) = {norvig / limit}")
print(f"k-gram accuracy ({kgram}) = {kgram / limit}")
